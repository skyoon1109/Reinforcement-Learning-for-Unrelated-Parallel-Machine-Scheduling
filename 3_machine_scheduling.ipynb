# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import copy
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import pandas as pd

import random
import itertools
from itertools import combinations as iter_combinations
from collections import Counter, defaultdict

# %%
# 학습 과정 시각화 그래프
def plot_training_curves(train_history, eval_history, loss_history, x_tick_size = 10, figsize=(20, 5)):
    plt.style.use('default')
    
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=figsize)
    
    # 1. Training Makespan 그래프
    ax1.plot(train_history, 
            color='#2E86C1',
            linewidth=2,
            markersize=4,
            markerfacecolor='white',
            label='Training Makespan')
    
    start = 0
    end = len(train_history)
    ax1.set_xticks(range(start, end, x_tick_size))
    ax1.set_xticklabels([str(x) for x in range(start, end, x_tick_size)])
    
    ax1.grid(True, linestyle='--', alpha=0.3)
    ax1.spines['top'].set_visible(False)
    ax1.spines['right'].set_visible(False)
    
    ax1.set_title('Training Makespan', fontsize=14, pad=15)
    ax1.set_xlabel('Epoch', fontsize=12)
    ax1.set_ylabel('Makespan', fontsize=12)
    ax1.legend(frameon=True, facecolor='white', edgecolor='none', fontsize=10)
    
    # 2. Evaluation Makespan 그래프
    ax2.plot(eval_history, 
            color='#E74C3C',
            linewidth=2,
            markersize=4,
            markerfacecolor='white',
            label='Evaluation Makespan')
    
    ax2.set_xticks(range(start, end, x_tick_size))
    ax2.set_xticklabels([str(x) for x in range(start, end, x_tick_size)])
    
    ax2.grid(True, linestyle='--', alpha=0.3)
    ax2.spines['top'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    
    ax2.set_title('Evaluation Makespan', fontsize=14, pad=15)
    ax2.set_xlabel('Epoch', fontsize=12)
    ax2.set_ylabel('Makespan', fontsize=12)
    ax2.legend(frameon=True, facecolor='white', edgecolor='none', fontsize=10)
    
    # 3. Loss 그래프
    ax3.plot(loss_history, 
            color='#27AE60', 
            linewidth=2,
            markersize=4,
            markerfacecolor='white',
            label='Training Loss')
    
    ax3.set_xticks(range(start, end, x_tick_size))
    ax3.set_xticklabels([str(x) for x in range(start, end, x_tick_size)])
    
    ax3.grid(True, linestyle='--', alpha=0.3)
    ax3.spines['top'].set_visible(False)
    ax3.spines['right'].set_visible(False)
    
    ax3.set_title('Training Loss', fontsize=14, pad=15)
    ax3.set_xlabel('Epoch', fontsize=12)
    ax3.set_ylabel('Loss', fontsize=12)
    ax3.legend(frameon=True, facecolor='white', edgecolor='none', fontsize=10)
    
    plt.tight_layout()
    
    plt.show()

# %% [markdown]
# # 단일 인스턴스 + POMO

# %%
def extract_machine_names(instance_data):
    """
    instance_data: dict with keys {"lots": [...], "process_info": [...]}
    process_info의 각 행에 "Machine" key가 있어야 합니다.
    """
    machines = sorted(list({row["Machine"] for row in instance_data["process_info"]}))
    return machines

class ParallelMachineEnvTimeProgressPOMO:
    def __init__(self, lots, process_info, machines, machine_order=None):
        """
        - lots: 한 인스턴스의 로트 데이터 (각 로트는 {'Lot_ID', 'Ready_time', 'Process_ID', ...})
        - process_info: 한 인스턴스의 프로세스 정보 (각 항목은 {'Process_ID', 'Machine', 'Mask_set', 'Processing_time'})
        - machines: 머신 이름들의 리스트 (예: ["M1", "M2", "M3"] 또는 그 이상)
        - machine_order: 머신 순서를 나타내는 리스트 (예: [2, 0, 1]이면 순서: 3번째, 1번째, 2번째). None이면 기본 순서.
        """
        self.lots = lots
        self.process_info = process_info
        self.machines = sorted(list(machines))
        
        # 마스크 집합 생성 (예: "MSK1/MSK2" → ["MSK1", "MSK2"])
        self.all_masks = set()
        for p in process_info:
            masks = p['Mask_set'].split('/')
            self.all_masks.update(masks)
        self.all_masks = sorted(list(self.all_masks))
        
        # 각 Process_ID에 대해 사용 가능한 머신 집합 계산
        self.process_machines = {}
        for p in process_info:
            self.process_machines.setdefault(p['Process_ID'], set()).add(p['Machine'])
        
        # POMO 머신 순서
        if machine_order is None:
            self.machine_order = list(range(len(self.machines)))
        else:
            self.machine_order = machine_order
        
        self.job_history = []
        
        self.reset()
    
    def reset(self):
        self.current_time = 0
        # 아직 도착하지 않은 로트들 (Lot_ID를 key로)
        self.pending_lots = {lot['Lot_ID']: lot for lot in self.lots}
        # 각 머신별 waiting list 초기화
        self.waiting_lists = {m: [] for m in self.machines}
        # 각 머신의 현재 작업 상태: None이면 Idle, 있으면 작업 정보를 담은 dict
        self.machine_status = {m: None for m in self.machines}
        # 마스크 사용 상태: 0이면 사용 가능, 양의 정수면 남은 사용시간
        self.mask_status = {mask: 0 for mask in self.all_masks}
        # 누적 통계
        self.machine_total_processing_times = {m: 0 for m in self.machines}
        self.machine_completed_jobs = {m: 0 for m in self.machines}
        self.mask_usage_count = {mask: 0 for mask in self.all_masks}
        self.machine_idle_time = {m: 0 for m in self.machines}
        self.completed_jobs = 0
        
        self.job_history = [] # 작업 히스토리 초기화
        return self.get_state()
    
    def _simulate_one_time_unit(self):
        for idx in self.machine_order:
            m = self.machines[idx]
            
            # (1) 머신이 현재 작업 중이면 remaining_time 감소
            if self.machine_status[m] is not None:
                job = self.machine_status[m]
                job['remaining_time'] -= 1
                self.machine_total_processing_times[m] += 1
                
                # 마스크 사용시간 1 감소
                if self.mask_status.get(job['mask'], 0) > 0:
                    self.mask_status[job['mask']] = max(0, self.mask_status[job['mask']] - 1)
                
                # 만약 남은 시간이 0 이하 => 작업 완료
                if job['remaining_time'] <= 0:
                    # 히스토리에 기록
                    self.job_history.append({
                        'machine': m,
                        'lot_id': job['lot']['Lot_ID'],
                        'process_id': job['lot']['Process_ID'],
                        'mask': job['mask'],
                        'start_time': self.current_time - job['process_time'],
                        'duration': job['process_time']
                    })
                    
                    # 완료 처리
                    self.machine_completed_jobs[m] += 1
                    self.completed_jobs += 1
                    self.mask_usage_count[job['mask']] += 1
                    self.mask_status[job['mask']] = 0
                    self.machine_status[m] = None
            
            # (2) 여기서 'if self.machine_status[m] is None:'로 처리
            #    => 방금 완료돼서 None이 된 머신도 포함된다!
            if self.machine_status[m] is None:
                # 대기열에서 새 작업 할당 가능하면 처리
                if self.waiting_lists[m]:
                    candidate_jobs = []
                    for lot in self.waiting_lists[m]:
                        # machine m에 맞는 process 정보 찾기
                        process_option = None
                        for p in self.process_info:
                            if p['Process_ID'] == lot['Process_ID'] and p['Machine'] == m:
                                process_option = p
                                break
                        if process_option is None:
                            continue
                        
                        # 사용가능 마스크 확인
                        masks = process_option['Mask_set'].split('/')
                        available_masks = [mask for mask in masks if self.mask_status[mask] == 0]
                        
                        # 마스크 하나라도 사용가능하면 후보에 추가
                        if available_masks:
                            least_used_mask = min(available_masks, key=lambda x: self.mask_usage_count[x])
                            candidate_jobs.append((lot, process_option, least_used_mask))
                    
                    if candidate_jobs:
                        # 처리시간이 가장 짧은 job 선택 => SPT 시퀀싱에 의해해
                        selected_lot, selected_process, selected_mask = min(
                            candidate_jobs, key=lambda x: x[1]['Processing_time']
                        )
                        # 대기열에서 제거
                        self.waiting_lists[m] = [
                            lot for lot in self.waiting_lists[m] if lot['Lot_ID'] != selected_lot['Lot_ID']
                        ]
                        # 머신에 새 작업 할당
                        self.machine_status[m] = {
                            'lot': selected_lot,
                            'remaining_time': selected_process['Processing_time'],
                            'mask': selected_mask,
                            'process_time': selected_process['Processing_time']
                        }
                        # 마스크도 사용중으로 설정
                        self.mask_status[selected_mask] = selected_process['Processing_time']
                    else:
                        # 후보가 없다면 idle 증가
                        self.machine_idle_time[m] += 1
                else:
                    # 대기열 자체가 비어있으면 idle 증가
                    self.machine_idle_time[m] += 1
        
        # 마지막에 시간 1 증가
        self.current_time += 1
        
    
    def _system_idle(self):
        return all(self.machine_status[m] is None for m in self.machines) and \
               all(len(self.waiting_lists[m]) == 0 for m in self.machines)
    
    def step(self, action=None):
        ready_lots = [lot for lot in self.pending_lots.values() if lot['Ready_time'] <= self.current_time]
        if ready_lots:
            lot = sorted(ready_lots, key=lambda x: x['Ready_time'])[0]
            if action is None:
                raise ValueError(f"Time {self.current_time}: Lot {lot['Lot_ID']} is ready (or overdue), but no action provided!")
            if action not in self.machines:
                raise ValueError(f"Invalid action: {action} is not a valid machine.")
            process_options = [p for p in self.process_info if p['Process_ID'] == lot['Process_ID'] and p['Machine'] == action]
            if not process_options:
                raise ValueError(f"Machine {action} is not eligible for Lot {lot['Lot_ID']} with process {lot['Process_ID']}.")
            self.waiting_lists[action].append(lot)
            del self.pending_lots[lot['Lot_ID']]
        
        while True:
            ready_lots = [lot for lot in self.pending_lots.values() if lot['Ready_time'] <= self.current_time]
            if ready_lots:
                break
            pending_ready_times = [lot['Ready_time'] for lot in self.pending_lots.values() if lot['Ready_time'] > self.current_time]
            if pending_ready_times:
                next_release_time = min(pending_ready_times)
                if self.current_time < next_release_time:
                    self._simulate_one_time_unit()
                else:
                    break
            else:
                if not self._system_idle():
                    self._simulate_one_time_unit()
                else:
                    break
        
        done = (len(self.pending_lots) == 0 and self._system_idle())
        reward = -self.current_time if done else 0
        info = {'current_time': self.current_time, 'completed_jobs': self.completed_jobs,
                'makespan': self.current_time if done else None}
        return self.get_state(), reward, done, info
    
    def get_state(self):
        state = []
        total_lots = len(self.lots)
        makespan = self.current_time if self.current_time > 0 else 1
        for m in self.machines:
            state.append(len(self.waiting_lists[m]) / total_lots if total_lots > 0 else 0)
        for mask in self.all_masks:
            state.append(1 if self.mask_status.get(mask, 0) == 0 else 0)
        for mask in self.all_masks:
            state.append(self.mask_usage_count[mask])
        next_ready_lot = None
        if self.pending_lots:
            next_ready_lot = sorted(self.pending_lots.values(), key=lambda x: x['Ready_time'])[0]
        if next_ready_lot:
            for m in self.machines:
                if m in self.process_machines.get(next_ready_lot['Process_ID'], []):
                    process = next((p for p in self.process_info if p['Process_ID'] == next_ready_lot['Process_ID'] and p['Machine'] == m), None)
                    state.append(process['Processing_time'] / makespan if process else 0)
                else:
                    state.append(0)
        else:
            state.extend([0] * len(self.machines))
        for m in self.machines:
            state.append(self.machine_total_processing_times[m] / makespan)
        for m in self.machines:
            state.append(self.machine_completed_jobs[m] / total_lots if total_lots > 0 else 0)
        for m in self.machines:
            state.append(self.machine_idle_time[m] / makespan)
        for m in self.machines:
            total_proc_time = 0
            for lot in self.waiting_lists[m]:
                process = next((p for p in self.process_info if p['Process_ID'] == lot['Process_ID'] and p['Machine'] == m), None)
                if process:
                    total_proc_time += process['Processing_time']
            state.append(total_proc_time / makespan)
        for m in self.machines:
            state.append(1 if self.machine_status[m] is None else 0)
        return state

# %% [markdown]
# # 배치 및 POMO 래퍼

# %%
class BatchParallelMachineEnvPOMO:
    def __init__(self, batch_data, machines):
        self.batch_size = len(batch_data)
        self.machines = machines
        self.pomo_orders = list(itertools.permutations(range(len(machines))))
        self.num_pomo = len(self.pomo_orders)
        self.batch_envs = []  # [B, num_pomo]
        for data in batch_data:
            lots = data["lots"]
            process_info = data["process_info"]
            instance_envs = []
            for order in self.pomo_orders:
                env = ParallelMachineEnvTimeProgressPOMO(lots, process_info, machines, machine_order=list(order))
                instance_envs.append(env)
            self.batch_envs.append(instance_envs)
    
    def reset(self):
        batch_states = []
        for instance_envs in self.batch_envs:
            instance_states = []
            for env in instance_envs:
                instance_states.append(env.reset())
            batch_states.append(torch.tensor(instance_states, dtype=torch.float))
        return torch.stack(batch_states, dim=0)  # [B, num_pomo, state_dim]
    
    def step(self, actions):
        batch_next_states = []
        batch_rewards = []
        batch_dones = []
        batch_infos = []
        for i, instance_envs in enumerate(self.batch_envs):
            instance_next_states = []
            instance_rewards = []
            instance_dones = []
            instance_infos = []
            for j, env in enumerate(instance_envs):
                state, reward, done, info = env.step(action=actions[i][j])
                instance_next_states.append(state)
                instance_rewards.append(reward)
                instance_dones.append(done)
                instance_infos.append(info)
            batch_next_states.append(torch.tensor(instance_next_states, dtype=torch.float))
            batch_rewards.append(torch.tensor(instance_rewards, dtype=torch.float))
            batch_dones.append(torch.tensor(instance_dones, dtype=torch.bool))
            batch_infos.append(instance_infos)
        return (torch.stack(batch_next_states, dim=0),
                torch.stack(batch_rewards, dim=0),
                torch.stack(batch_dones, dim=0),
                batch_infos)
    
    def get_final_makespans(self):
        makespans = []
        for instance_envs in self.batch_envs:
            instance_makespans = []
            for env in instance_envs:
                instance_makespans.append(env.current_time)
            makespans.append(instance_makespans)
        return torch.tensor(makespans, dtype=torch.float)  # [B, num_pomo]

# %% [markdown]
# # 정책 네트워크 + 에이전트

# %%
class PolicyNetwork(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim, machine_names):
        super().__init__()
        self.machine_names = machine_names
        layers = []
        last_dim = input_dim
        for _ in range(num_layers):
            layers.append(nn.Linear(last_dim, hidden_dim))
            layers.append(nn.ReLU())
            last_dim = hidden_dim
        layers.append(nn.Linear(last_dim, output_dim))
        self.model = nn.Sequential(*layers)
    
    def forward(self, x):
        # [N, state_dim] -> [N, output_dim]
        return self.model(x)
    
class REINFORCEAgent:
    def __init__(self, state_dim, hidden_dim, num_layers, num_actions, machine_names, lr=1e-3, device='cuda'):
        self.device = device
        self.machine_names = machine_names
        self.num_actions = num_actions
        self.policy_net = PolicyNetwork(state_dim, hidden_dim, num_layers, num_actions, machine_names).to(self.device)
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=lr)
    
    def rollout_batch(self, batch_env, greedy = False):
        B = batch_env.batch_size
        P = batch_env.num_pomo
        state = batch_env.reset().to(self.device)     # [B, P, state_dim]
        done_mask = torch.zeros(B, P, dtype=torch.bool, device=self.device)
        log_prob_sum = torch.zeros(B, P, device=self.device)
        final_rewards = torch.zeros(B, P, device=self.device)
        
        while not done_mask.all():
            actions = []
            flat_states = []
            indices = []
            env_refs = []
            for i in range(B):
                row_act = []
                for j in range(P):
                    env = batch_env.batch_envs[i][j]
                    # ready lot?
                    if any(lot['Ready_time']<=env.current_time for lot in env.pending_lots.values()):
                        flat_states.append(state[i,j])
                        indices.append((i,j))
                        env_refs.append(env)
                        row_act.append(None)
                    else:
                        row_act.append(None)
                actions.append(row_act)
            
            if flat_states:
                fs_tensor = torch.stack(flat_states, dim=0)  # [N, state_dim]
                logits = self.policy_net(fs_tensor)
                
                # 마스킹
                for idx, env in enumerate(env_refs):
                    rdy = [lot for lot in env.pending_lots.values()
                           if lot['Ready_time']<=env.current_time]
                    if rdy:
                        chosen_lot = sorted(rdy, key=lambda x: x['Ready_time'])[0]
                        elig = {
                            p['Machine'] for p in env.process_info
                            if p['Process_ID']==chosen_lot['Process_ID']
                        }
                        for a in range(self.num_actions):
                            if self.machine_names[a] not in elig:
                                logits[idx,a] = -1e9
                                
                probs = F.softmax(logits, dim=-1)
                if greedy:
                    sampled = torch.argmax(probs, dim=-1)
                    log_probs = torch.log(probs.gather(1, sampled.unsqueeze(-1))).squeeze(-1)
                else:
                    m = torch.distributions.Categorical(probs)
                    sampled = m.sample()
                    log_probs = m.log_prob(sampled)
                    
                for k, (i,j) in enumerate(indices):
                    act_idx = sampled[k].item()
                    act_name = self.machine_names[act_idx]
                    actions[i][j] = act_name
                    log_prob_sum[i,j] += log_probs[k]
            
            next_state, rewards, dones, _ = batch_env.step(actions)
            next_state = next_state.to(self.device)
            for i in range(B):
                for j in range(P):
                    if dones[i,j] and not done_mask[i,j]:
                        final_rewards[i,j] = rewards[i,j]
                        done_mask[i,j] = True
            state = next_state
        
        return log_prob_sum, final_rewards
    
    def evaluate_batch(self, batch_env):
        """
        배치의 각 인스턴스에 대해 POMO별로 greedy한 솔루션을 생성하고,
        각 인스턴스별로 가장 좋은 makespan을 선택
        """
        _, final_rewards = self.rollout_batch(batch_env, greedy=True)
        makespans = -final_rewards  # reward가 -makespan이므로
        # 각 인스턴스별로 가장 좋은(작은) makespan 선택
        best_makespans = makespans.min(dim=1)[0]  # [B]
        return best_makespans.mean().item()  # 배치 평균
        
    def update(self, log_prob_sum, final_rewards):
        baseline = final_rewards.mean(dim=1, keepdim=True)  # [B,1], POMO Average Baseline 사용용
        adv = final_rewards - baseline  # [B,P], Advantage 계산산
        loss = - (log_prob_sum * adv).mean() # loss 계산 (REINFORCE)
        self.optimizer.zero_grad() 
        loss.backward()
        self.optimizer.step()
        return loss.item(), final_rewards.mean().item()

# %% [markdown]
# # 학습

# %% [markdown]
# ## 데이터 생성

# %%
# 환경 파라미터
num_lots = 20
num_machines = 3

num_processes = num_lots // 2  # Process_ID의 개수는 로트 개수의 절반
num_masks = num_machines  # 전체 마스크의 개수는 기계 수와 같다.
min_machines_per_process = 2
max_machines_per_process = 3
min_masks_per_combo = 2
max_masks_per_combo = 3
min_masks_per_process = 2
max_masks_per_process = 3
min_processing_time = 20
max_processing_time = 50
interval_size=5

# %%
# Data Generation Function
def generate_photolithography_data(num_lots=10, num_processes=5, num_machines=3, num_masks=3,
                                min_machines_per_process=2, max_machines_per_process=3,
                                min_masks_per_combo=2, max_masks_per_combo=3,
                                min_masks_per_process=2, max_masks_per_process=3,
                                min_processing_time=20, max_processing_time=50,
                                interval_size=15,  # 구간 크기
                                random_seed=None):

    if random_seed is None:
        random_seed = random.randint(1, 1000000)

    random.seed(random_seed)
    process_configs = {}
    all_machines = [f'M{j}' for j in range(1, num_machines + 1)]
    all_masks = [f'MSK{k}' for k in range(1, num_masks + 1)]

    machine_usage = Counter()  
    mask_usage = Counter()     
    machine_mask_usage = defaultdict(Counter)  

    def get_least_used_machines(num_needed):
        sorted_machines = sorted(all_machines, key=lambda m: machine_usage[m])
        return sorted_machines[:num_needed]

    def get_least_used_masks(num_needed, exclude_masks=None):
        available_masks = set(all_masks) - (set(exclude_masks) if exclude_masks else set())
        if len(available_masks) < num_needed:
            available_masks = set(all_masks)
        sorted_masks = sorted(list(available_masks), key=lambda m: mask_usage[m])
        return sorted_masks[:num_needed]

    # Process 설정 생성
    for i in range(1, num_processes + 1):
        process_id = f'P{str(i).zfill(2)}'
        
        # Process에 할당할 Machine 수 결정
        num_machines_for_process = min(
            random.randint(min_machines_per_process, max_machines_per_process),
            len(all_machines)
        )
        
        selected_machines = get_least_used_machines(num_machines_for_process)
        machine_configs = {}
        process_masks = set()
        
        # 각 Machine에 mask 할당 (최소 개수 보장)
        for machine in selected_machines:
            # 각 Machine은 최소 min_masks_per_combo개의 Mask를 가져야 함
            num_masks_for_machine = random.randint(min_masks_per_combo, max_masks_per_combo)
            
            # 현재까지 가장 적게 사용된 Mask들 선택
            available_masks = get_least_used_masks(num_masks_for_machine, process_masks)
            
            # Mask 사용 횟수 업데이트
            for mask in available_masks:
                mask_usage[mask] += 1
                machine_mask_usage[machine][mask] += 1
                process_masks.add(mask)
            
            # Machine 구성 저장
            machine_configs[machine] = {
                'mask_set': available_masks,
                'processing_time': random.randint(min_processing_time, max_processing_time)
            }
            machine_usage[machine] += 1
        
        # Process의 최소 Mask 개수 확인 및 보장
        while len(process_masks) < min_masks_per_process:
            # 가장 적게 사용된 Machine 선택
            target_machine = min(machine_configs.keys(), 
                               key=lambda m: len(machine_configs[m]['mask_set']))
            
            # 아직 사용되지 않은 Mask 중 가장 적게 사용된 것 선택
            new_mask = get_least_used_masks(1, process_masks)[0]
            
            # Mask 추가
            machine_configs[target_machine]['mask_set'].append(new_mask)
            mask_usage[new_mask] += 1
            machine_mask_usage[target_machine][new_mask] += 1
            process_masks.add(new_mask)
        
        process_configs[process_id] = {
            'eligible_masks': list(process_masks),
            'machine_configs': machine_configs
        }

    # Process-Machine-Mask 조합 DataFrame 생성
    combination_data = []
    for process_id, config in process_configs.items():
        for machine, machine_config in config['machine_configs'].items():
            # 각 Machine의 Mask set이 최소 개수를 만족하는지 확인
            current_masks = machine_config['mask_set']
            while len(current_masks) < min_masks_per_combo:
                new_mask = get_least_used_masks(1, current_masks)[0]
                current_masks.append(new_mask)
                mask_usage[new_mask] += 1
                machine_mask_usage[machine][new_mask] += 1
            
            combination_data.append({
                'Process_ID': process_id,
                'Machine': machine,
                'Mask_set': '/'.join(current_masks),
                'Processing_time': machine_config['processing_time']
            })
    
    combination_df = pd.DataFrame(combination_data)

    lot_data = []
    process_ids = list(process_configs.keys()) 
    ready_times = []
    
    # Ready time 생성
    for i in range(num_lots):
        start_time = i * interval_size
        end_time = (i + 1) * interval_size
        ready_times.append(random.randint(start_time, end_time))
    
    # 첫 번째 그룹 Process_ID 할당
    first_group_processes = random.sample(process_ids, len(process_ids))
    for i in range(num_lots // 2):
        lot_data.append({
            'Lot_ID': f'L{str(i+1).zfill(2)}',
            'Process_ID': first_group_processes[i % len(process_ids)],
            'Ready_time': ready_times[i]
        })
    
    # 두 번째 그룹 (L{num_lots//2 + 1}-L{num_lots}) Process_ID 할당
    second_group_processes = random.sample(process_ids, len(process_ids))
    for i in range(num_lots // 2, num_lots):
        lot_data.append({
            'Lot_ID': f'L{str(i+1).zfill(2)}',
            'Process_ID': second_group_processes[(i - num_lots // 2) % len(process_ids)],
            'Ready_time': ready_times[i]
        })

    lot_df = pd.DataFrame(lot_data)
    return combination_df, lot_df, random_seed

# 인스턴스 데이타 생성 함수수
def generate_instance_data(seed = None):
    combination_df, lot_df, seed = generate_photolithography_data(
        num_lots=num_lots,
        num_processes=num_processes,
        num_machines=num_machines,
        num_masks=num_masks,
        min_machines_per_process=min_machines_per_process,
        max_machines_per_process=max_machines_per_process,
        min_masks_per_combo=min_masks_per_combo,
        max_masks_per_combo=max_masks_per_combo,
        min_masks_per_process=min_masks_per_process,
        max_masks_per_process=max_masks_per_process,
        min_processing_time=min_processing_time,
        max_processing_time=max_processing_time,
        interval_size = interval_size,
        random_seed=seed
    )
    
    instance_data = {
        "lots": lot_df.to_dict(orient="records"),
        "process_info": combination_df.to_dict(orient="records")
    }
    return instance_data

# 배치 단위 환경 생성 함수 
def batch_env_fn(batch_size):
    batch_data = [copy.deepcopy(generate_instance_data()) for _ in range(batch_size)]
    dummy_instance = batch_data[0]
    machines = extract_machine_names(dummy_instance)
    return BatchParallelMachineEnvPOMO(batch_data, machines)

# %% [markdown]
# ## 학습 루프

# %%
def create_gantt_chart(scheduling_history, env):
    """스케줄링 결과를 matplotlib을 이용해 간트 차트로 시각화 - Mask 기준 색상"""
    # Mask별 색상 매핑 생성
    masks = set([f'MSK{i}' for i in range(1, num_machines + 1)])
    colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#FFEEAD',
              '#D4A5A5', '#9370DB', '#20B2AA', '#FFD93D', '#FF8C42',
              '#98FB98', '#DDA0DD', '#40E0D0', '#FF6B6B', '#4ECDC4']
    
    colors = colors[:len(masks)]
    mask_colors = dict(zip(masks, colors))

    fig, ax = plt.subplots(figsize=(15, len(env.machines) * 2))
    plt.subplots_adjust(right=0.85)
    
    ax.set_facecolor('white')
    fig.patch.set_facecolor('white')

    machines = sorted(env.machines)
    ax.set_ylim(-0.5, len(machines) - 0.5)
    ax.set_yticks(range(len(machines)))
    ax.set_yticklabels(reversed(machines), fontsize=10)

    ax.grid(True, axis='x', alpha=0.3, linestyle='--', color='gray')

    bar_height = 0.7
    max_time = 0
    for event in scheduling_history:
        machine_idx = len(machines) - 1 - sorted(env.machines).index(event['machine'])
        end_time = event['start_time'] + event['duration']
        max_time = max(max_time, end_time)
        
        ax.barh(machine_idx,
                event['duration'],
                left=event['start_time'],
                height=bar_height,
                color=mask_colors[event['mask']],
                alpha=0.9,
                edgecolor='black',
                linewidth=1.5,
                zorder=2)
                
        text = f"L{event['lot_id']}\nP{event['process_id']}\n{event['mask']}"
        text_x = event['start_time'] + event['duration'] / 2
        
        text_bbox = dict(boxstyle='round,pad=0.5', 
                        facecolor='white', 
                        alpha=0.7,
                        edgecolor='none')
        
        ax.text(text_x,
                machine_idx,
                text,
                horizontalalignment='center',
                verticalalignment='center',
                fontsize=9,
                bbox=text_bbox,
                zorder=3)

    ax.axvline(x=max_time, color='red', linestyle='--', linewidth=2, label='Makespan', zorder=4)

    ax.set_xlim(0, max_time * 1.05)

    ticks = np.arange(0, max_time + 50, 50)

    ticks = np.sort(np.append(ticks, max_time))
    ax.set_xticks(ticks)
    

    tick_labels = [str(int(tick)) for tick in ticks]
    ax.set_xticklabels(tick_labels, fontsize=10)
    

    for i, tick in enumerate(ticks):
        if tick == max_time:
            ax.get_xticklabels()[i].set_color('red')


    ax.set_xlabel('Time', fontsize=12)
    ax.set_ylabel('Machines', fontsize=12)
    ax.set_title('Machine Schedule Gantt Chart', fontsize=14, pad=20)


    legend_elements = [plt.Rectangle((0,0), 1, 1,
                                   facecolor=color,
                                   edgecolor='black',
                                   linewidth=1.5,
                                   label=f'Mask {mask}')
                      for mask, color in mask_colors.items()]
    legend_elements.append(plt.Line2D([0], [0], color='red', linestyle='--', 
                                    linewidth=2, label='Makespan'))
    
    ax.legend(handles=legend_elements,
             loc='center left',
             bbox_to_anchor=(1.02, 0.5),
             fontsize=10,
             frameon=True,
             facecolor='white',
             edgecolor='lightgray')

    plt.tight_layout()
    return fig, ax

def create_pomo_gantt_chart(instance_data, agent, machines):
    env = BatchParallelMachineEnvPOMO([instance_data], machines)
    agent.policy_net.eval()

    with torch.no_grad():
        # 모든 POMO 솔루션 생성
        _, final_rewards = agent.rollout_batch(env, greedy=True)
        makespans = -final_rewards  # reward가 -makespan이므로
        
        best_pomo_idx = torch.argmin(makespans[0]).item()
        best_env = env.batch_envs[0][best_pomo_idx]
        
        fig, ax = create_gantt_chart(best_env.job_history, best_env)
        
        print(f"\nBest POMO Solution:")
        print(f"Makespan: {best_env.current_time:.2f}")
        print(f"Total jobs completed: {len(best_env.job_history)}")
        
        return fig, ax, best_env.job_history

# %%
import time
def train_agent(num_epochs=5, num_batch=100, batch_size=32, eval_size=40, device='cpu'):
    """
    num_epochs: 전체 epoch 수
    num_batch: 한 epoch 내에서 몇 번의 배치를 돌릴지
    batch_size: 한 배치에 포함되는 인스턴스 개수
    """
    # 1) dummy로 env/agent 준비
    dummy_data = generate_instance_data()
    machines = extract_machine_names(dummy_data)
    dummy_env = ParallelMachineEnvTimeProgressPOMO(dummy_data["lots"], dummy_data["process_info"], machines)
    dummy_state = dummy_env.reset()
    state_dim = len(dummy_state) if isinstance(dummy_state, (list, tuple)) else dummy_state.shape[-1]
    num_actions = len(machines)
    
    agent = REINFORCEAgent(
        state_dim=state_dim,
        hidden_dim=128,
        num_layers=2,
        num_actions=num_actions,
        machine_names=machines,
        lr=1e-3,
        device=device
    )
    
    makespan_history = [] # epoch별 평균 makespan 기록
    eval_makespan_history = [] # epoch 별 eval 평균 기록
    loss_history = [] # epoch 별 loss 기록
    
    total_start_time = time.time()
    for epoch in range(num_epochs):
        epoch_start_time = time.time()
        epoch_loss = 0.0
        epoch_reward = 0.0
        epoch_makespan = 0.0
        
        print(f"\n=== [Epoch {epoch+1}/{num_epochs}] ===")
        
        agent.policy_net.train()
        for b in range(num_batch):
            # batch_size개의 인스턴스 생성
            batch_data = [copy.deepcopy(generate_instance_data()) for _ in range(batch_size)]
            # batch_env
            pomo_env = BatchParallelMachineEnvPOMO(batch_data, machines)
            
            # rollout
            log_prob_sum, final_rewards = agent.rollout_batch(pomo_env)
            
            # update
            loss, avg_reward = agent.update(log_prob_sum, final_rewards)
            epoch_loss += loss
            epoch_reward += avg_reward
            
            # 각 배치에서 최종 makespan
            # pomo_env.get_final_makespans(): shape [B,P]
            final_ms = pomo_env.get_final_makespans()  # [B,P]
            avg_ms = final_ms.mean().item()            # B*P 중 평균
            epoch_makespan += avg_ms
            
            if (b+1) % 10 == 0:
                print(f" Batch {b+1}/{num_batch}: loss={loss:.4f}, reward={avg_reward:.4f}, makespan={avg_ms:.1f}")
        
        # epoch 단위 평균 loss, reward, makespan
        epoch_loss_avg = epoch_loss / num_batch
        epoch_reward_avg = epoch_reward / num_batch
        epoch_makespan_avg = epoch_makespan / num_batch
        makespan_history.append(epoch_makespan_avg)
        loss_history.append(epoch_loss_avg)
        epoch_end_time = time.time()
        print(f"[Epoch {epoch+1}] => loss={epoch_loss_avg:.4f}, reward={epoch_reward_avg:.4f}, makespan={epoch_makespan_avg:.1f}")
        print(f'[Epoch {epoch+1} 학습 시간] : {epoch_end_time - epoch_start_time:.2f} 초')
        
        # Evaluation Phase
        print("\nEvaluating...")
        evaluation_start_time = time.time()
        agent.policy_net.eval()  # 평가 모드로 설정
        eval_size_list = [batch_size] * (eval_size // batch_size) + ([eval_size % batch_size] if eval_size % batch_size != 0 else [])
        eval_temp_list = []
        for size in eval_size_list:
            eval_data = [copy.deepcopy(generate_instance_data()) for _ in range(size)]
            eval_env = BatchParallelMachineEnvPOMO(eval_data, machines)
            with torch.no_grad():  # 그래디언트 계산 비활성화
                avg_makespan = agent.evaluate_batch(eval_env)
            eval_temp_list.append(avg_makespan)
        eval_makespan_history.append(np.mean(eval_temp_list))
        evaluation_end_time = time.time()
        print(f'Evaluation {epoch+1} => makespan = {eval_makespan_history[-1]}')
        print(f'Evaluation {epoch+1} 평가 시간 : {evaluation_end_time - evaluation_start_time:.2f} 초')
    
    total_end_time = time.time()
    print()
    total_time = total_end_time - total_start_time
    minutes = int(total_time // 60)
    seconds = int(total_time % 60)   
    print(f'전체 학습 시간 : {minutes}분 {seconds}초')
    
    return agent, makespan_history, eval_makespan_history, loss_history

# %%
if __name__ == "__main__":
    trained_agent, ms_history, eval_ms_history, loss_history = train_agent(num_epochs=300, num_batch=50, batch_size=25, eval_size=300, device='cuda')
    
    plot_training_curves(ms_history, eval_ms_history, loss_history, x_tick_size=20)
# Out:
# === [Epoch 1/300] ===
#  Batch 10/50: loss=-5.6506, reward=-308.0667, makespan=308.1
#  Batch 20/50: loss=-7.9863, reward=-298.5600, makespan=298.6
#  Batch 30/50: loss=-15.3760, reward=-296.5600, makespan=296.6
#  Batch 40/50: loss=-10.7076, reward=-280.1933, makespan=280.2
#  Batch 50/50: loss=-10.3626, reward=-285.2200, makespan=285.2
# [Epoch 1] => loss=-7.8250, reward=-300.2009, makespan=300.2
# [Epoch 1 학습 시간] : 41.73 초
#
# Evaluating...
# Evaluation 1 => makespan = 259.5933265686035
# Evaluation 1 평가 시간 : 4.81 초
#
# === [Epoch 2/300] ===
#  Batch 10/50: loss=-6.7455, reward=-278.7333, makespan=278.7
#  Batch 20/50: loss=-2.7667, reward=-276.1000, makespan=276.1
#  Batch 30/50: loss=-7.3923, reward=-271.3000, makespan=271.3
#  Batch 40/50: loss=-3.0097, reward=-271.9733, makespan=272.0
#  Batch 50/50: loss=-3.9637, reward=-263.1933, makespan=263.2
# [Epoch 2] => loss=-7.8391, reward=-274.8561, makespan=274.9
# [Epoch 2 학습 시간] : 39.45 초
#
# Evaluating...
# Evaluation 2 => makespan = 255.9766591389974
# Evaluation 2 평가 시간 : 4.78 초
#
# === [Epoch 3/300] ===
#  Batch 10/50: loss=-6.7769, reward=-266.4200, makespan=266.4
#  Batch 20/50: loss=-2.2897, reward=-270.4467, makespan=270.4
#  Batch 30/50: loss=-9.7099, reward=-261.6667, makespan=261.7
#  Batch 40/50: loss=-8.6060, reward=-263.7267, makespan=263.7
#  Batch 50/50: loss=-10.6213, reward=-264.3400, makespan=264.3
# [Epoch 3] => loss=-7.9046, reward=-265.7800, makespan=265.8
# [Epoch 3 학습 시간] : 40.12 초
#
# Evaluating...
# Evaluation 3 => makespan = 253.3466593424479
# Evaluation 3 평가 시간 : 4.83 초
#
# === [Epoch 4/300] ===
#  Batch 10/50: loss=-8.9885, reward=-259.0067, makespan=259.0
#  Batch 20/50: loss=-7.3252, reward=-261.9467, makespan=261.9
#  Batch 30/50: loss=-8.5627, reward=-256.5533, makespan=256.6
#  Batch 40/50: loss=-13.3445, reward=-258.6333, makespan=258.6
#  Batch 50/50: loss=-6.3139, reward=-260.1933, makespan=260.2
# [Epoch 4] => loss=-8.1357, reward=-260.3271, makespan=260.3
# [Epoch 4 학습 시간] : 39.06 초
#
# Evaluating...
# Evaluation 4 => makespan = 249.59666061401367
# Evaluation 4 평가 시간 : 4.79 초
#
# === [Epoch 5/300] ===
#  Batch 10/50: loss=-12.5369, reward=-253.9733, makespan=254.0
#  Batch 20/50: loss=-7.5424, reward=-260.1933, makespan=260.2
#  Batch 30/50: loss=-4.9019, reward=-253.7200, makespan=253.7
#  Batch 40/50: loss=-7.6914, reward=-254.8267, makespan=254.8
#  Batch 50/50: loss=-6.6036, reward=-250.3533, makespan=250.4
# [Epoch 5] => loss=-7.8722, reward=-256.0131, makespan=256.0
# [Epoch 5 학습 시간] : 39.57 초
#
# Evaluating...
# Evaluation 5 => makespan = 246.64999389648438
# Evaluation 5 평가 시간 : 4.77 초
#
# === [Epoch 6/300] ===
#  Batch 10/50: loss=-9.6220, reward=-254.9867, makespan=255.0
#  Batch 20/50: loss=-13.1939, reward=-248.2867, makespan=248.3
#  Batch 30/50: loss=-13.2699, reward=-252.7533, makespan=252.8
#  Batch 40/50: loss=-10.4786, reward=-246.2000, makespan=246.2
#  Batch 50/50: loss=-10.6762, reward=-249.1867, makespan=249.2
# [Epoch 6] => loss=-9.2999, reward=-251.8024, makespan=251.8
# [Epoch 6 학습 시간] : 39.52 초
#
# Evaluating...
# Evaluation 6 => makespan = 244.8899943033854
# Evaluation 6 평가 시간 : 4.78 초
#
# === [Epoch 7/300] ===
#  Batch 10/50: loss=-9.6288, reward=-243.7200, makespan=243.7
#  Batch 20/50: loss=-6.4943, reward=-252.6533, makespan=252.7
#  Batch 30/50: loss=-9.9323, reward=-239.0533, makespan=239.1
#  Batch 40/50: loss=-5.9831, reward=-250.5400, makespan=250.5
#  Batch 50/50: loss=-11.5350, reward=-241.5667, makespan=241.6
# [Epoch 7] => loss=-9.0532, reward=-248.5209, makespan=248.5
# [Epoch 7 학습 시간] : 39.02 초
#
# Evaluating...
# Evaluation 7 => makespan = 240.40999348958334
# Evaluation 7 평가 시간 : 4.70 초
#
# === [Epoch 8/300] ===
#  Batch 10/50: loss=-12.8519, reward=-247.8533, makespan=247.9
#  Batch 20/50: loss=-13.2233, reward=-238.4600, makespan=238.5
#  Batch 30/50: loss=-5.9472, reward=-247.0467, makespan=247.0
#  Batch 40/50: loss=-12.9334, reward=-239.1067, makespan=239.1
#  Batch 50/50: loss=-5.1431, reward=-248.1067, makespan=248.1
# [Epoch 8] => loss=-9.2858, reward=-245.2833, makespan=245.3
# [Epoch 8 학습 시간] : 38.62 초
#
# Evaluating...
# Evaluation 8 => makespan = 239.38332875569662
# Evaluation 8 평가 시간 : 4.75 초
#
# === [Epoch 9/300] ===
#  Batch 10/50: loss=-6.8507, reward=-247.6333, makespan=247.6
#  Batch 20/50: loss=-5.9190, reward=-244.7933, makespan=244.8
#  Batch 30/50: loss=-3.8380, reward=-246.1133, makespan=246.1
#  Batch 40/50: loss=-6.6568, reward=-243.7800, makespan=243.8
#  Batch 50/50: loss=-3.6811, reward=-245.5000, makespan=245.5
# [Epoch 9] => loss=-8.1638, reward=-244.2407, makespan=244.2
# [Epoch 9 학습 시간] : 38.95 초
#
# Evaluating...
# Evaluation 9 => makespan = 238.36666107177734
# Evaluation 9 평가 시간 : 4.66 초
#
# === [Epoch 10/300] ===
#  Batch 10/50: loss=-5.5721, reward=-246.4067, makespan=246.4
#  Batch 20/50: loss=-7.2733, reward=-243.3600, makespan=243.4
#  Batch 30/50: loss=-4.8507, reward=-247.6133, makespan=247.6
#  Batch 40/50: loss=-14.5632, reward=-239.8400, makespan=239.8
#  Batch 50/50: loss=-4.5010, reward=-247.3733, makespan=247.4
# [Epoch 10] => loss=-7.9711, reward=-241.9296, makespan=241.9
# [Epoch 10 학습 시간] : 38.65 초
#
# Evaluating...
# Evaluation 10 => makespan = 235.5666618347168
# Evaluation 10 평가 시간 : 4.71 초
#
# === [Epoch 11/300] ===
#  Batch 10/50: loss=-6.0023, reward=-242.0333, makespan=242.0
#  Batch 20/50: loss=-10.3116, reward=-236.5200, makespan=236.5
#  Batch 30/50: loss=-8.0799, reward=-243.7467, makespan=243.7
#  Batch 40/50: loss=-9.2469, reward=-240.5533, makespan=240.6
#  Batch 50/50: loss=-6.3181, reward=-241.5533, makespan=241.6
# [Epoch 11] => loss=-7.0561, reward=-240.6351, makespan=240.6
# [Epoch 11 학습 시간] : 39.57 초
#
# Evaluating...
# Evaluation 11 => makespan = 234.12332916259766
# Evaluation 11 평가 시간 : 4.67 초
#
# === [Epoch 12/300] ===
#  Batch 10/50: loss=-7.6727, reward=-234.6733, makespan=234.7
#  Batch 20/50: loss=-10.0285, reward=-238.2467, makespan=238.2
#  Batch 30/50: loss=-9.2498, reward=-233.4933, makespan=233.5
#  Batch 40/50: loss=-4.4791, reward=-236.4533, makespan=236.5
#  Batch 50/50: loss=-6.5731, reward=-236.3000, makespan=236.3
# [Epoch 12] => loss=-7.2628, reward=-240.0493, makespan=240.0
# [Epoch 12 학습 시간] : 38.99 초
#
# Evaluating...
# Evaluation 12 => makespan = 235.54666392008463
# Evaluation 12 평가 시간 : 4.73 초
#
# === [Epoch 13/300] ===
#  Batch 10/50: loss=-7.5556, reward=-244.1800, makespan=244.2
#  Batch 20/50: loss=-4.3713, reward=-235.7667, makespan=235.8
#  Batch 30/50: loss=-5.9640, reward=-247.1867, makespan=247.2
#  Batch 40/50: loss=-5.2038, reward=-235.9200, makespan=235.9
#  Batch 50/50: loss=-4.5538, reward=-245.0267, makespan=245.0
# [Epoch 13] => loss=-6.1508, reward=-239.7896, makespan=239.8
# [Epoch 13 학습 시간] : 42.06 초
#
# Evaluating...
# Evaluation 13 => makespan = 233.53999455769858
# Evaluation 13 평가 시간 : 4.73 초
#
# === [Epoch 14/300] ===
#  Batch 10/50: loss=-3.8257, reward=-233.4800, makespan=233.5
#  Batch 20/50: loss=-3.6919, reward=-241.9467, makespan=241.9
#  Batch 30/50: loss=-4.8584, reward=-235.3200, makespan=235.3
#  Batch 40/50: loss=-3.2122, reward=-240.3000, makespan=240.3
#  Batch 50/50: loss=-6.5565, reward=-238.3800, makespan=238.4
# [Epoch 14] => loss=-5.8236, reward=-239.8659, makespan=239.9
# [Epoch 14 학습 시간] : 39.18 초
#
# Evaluating...
# Evaluation 14 => makespan = 236.6133270263672
# Evaluation 14 평가 시간 : 4.67 초
#
# === [Epoch 15/300] ===
#  Batch 10/50: loss=-5.5657, reward=-237.5800, makespan=237.6
#  Batch 20/50: loss=-2.1576, reward=-242.5333, makespan=242.5
#  Batch 30/50: loss=-2.7577, reward=-239.2133, makespan=239.2
#  Batch 40/50: loss=-8.0772, reward=-238.5867, makespan=238.6
#  Batch 50/50: loss=-3.8873, reward=-240.3200, makespan=240.3
# [Epoch 15] => loss=-5.0447, reward=-239.0159, makespan=239.0
# [Epoch 15 학습 시간] : 38.54 초
#
# Evaluating...
# Evaluation 15 => makespan = 234.88666152954102
# Evaluation 15 평가 시간 : 4.71 초
#
# === [Epoch 16/300] ===
#  Batch 10/50: loss=-5.1853, reward=-238.1467, makespan=238.1
#  Batch 20/50: loss=-4.0817, reward=-245.5067, makespan=245.5
#  Batch 30/50: loss=-4.9985, reward=-237.1667, makespan=237.2
#  Batch 40/50: loss=-6.6245, reward=-249.4733, makespan=249.5
#  Batch 50/50: loss=-4.0314, reward=-238.5933, makespan=238.6
# [Epoch 16] => loss=-5.0412, reward=-238.1861, makespan=238.2
# [Epoch 16 학습 시간] : 38.20 초
#
# Evaluating...
# Evaluation 16 => makespan = 236.6333262125651
# Evaluation 16 평가 시간 : 4.67 초
#
# === [Epoch 17/300] ===
#  Batch 10/50: loss=-4.5537, reward=-236.7333, makespan=236.7
#  Batch 20/50: loss=-4.5949, reward=-239.4667, makespan=239.5
#  Batch 30/50: loss=-1.8053, reward=-233.3400, makespan=233.3
#  Batch 40/50: loss=-5.2516, reward=-237.8867, makespan=237.9
#  Batch 50/50: loss=-9.7885, reward=-233.3533, makespan=233.4
# [Epoch 17] => loss=-5.0547, reward=-237.4700, makespan=237.5
# [Epoch 17 학습 시간] : 38.52 초
#
# Evaluating...
# Evaluation 17 => makespan = 234.1766611735026
# Evaluation 17 평가 시간 : 4.80 초
#
# === [Epoch 18/300] ===
#  Batch 10/50: loss=-5.0718, reward=-236.8667, makespan=236.9
#  Batch 20/50: loss=-3.5738, reward=-233.2933, makespan=233.3
#  Batch 30/50: loss=-7.7846, reward=-237.9667, makespan=238.0
#  Batch 40/50: loss=-6.1764, reward=-235.6267, makespan=235.6
#  Batch 50/50: loss=-7.3848, reward=-236.5067, makespan=236.5
# [Epoch 18] => loss=-4.8625, reward=-237.4051, makespan=237.4
# [Epoch 18 학습 시간] : 38.59 초
#
# Evaluating...
# Evaluation 18 => makespan = 235.9033292134603
# Evaluation 18 평가 시간 : 4.67 초
#
# === [Epoch 19/300] ===
#  Batch 10/50: loss=-6.8772, reward=-238.4667, makespan=238.5
#  Batch 20/50: loss=-3.9045, reward=-241.9467, makespan=241.9
#  Batch 30/50: loss=-5.9075, reward=-235.2067, makespan=235.2
#  Batch 40/50: loss=-4.4330, reward=-240.8133, makespan=240.8
#  Batch 50/50: loss=-8.5995, reward=-236.6400, makespan=236.6
# [Epoch 19] => loss=-4.4610, reward=-237.4309, makespan=237.4
# [Epoch 19 학습 시간] : 39.30 초
#
# Evaluating...
# Evaluation 19 => makespan = 234.16999435424805
# Evaluation 19 평가 시간 : 4.73 초
#
# === [Epoch 20/300] ===
#  Batch 10/50: loss=-5.8203, reward=-237.6333, makespan=237.6
#  Batch 20/50: loss=-2.8295, reward=-232.2333, makespan=232.2
#  Batch 30/50: loss=-4.0095, reward=-238.2667, makespan=238.3
#  Batch 40/50: loss=-7.2577, reward=-239.0933, makespan=239.1
#  Batch 50/50: loss=-0.8698, reward=-233.7800, makespan=233.8
# [Epoch 20] => loss=-4.1334, reward=-236.7933, makespan=236.8
# [Epoch 20 학습 시간] : 39.02 초
#
# Evaluating...
# Evaluation 20 => makespan = 235.7766596476237
# Evaluation 20 평가 시간 : 4.68 초
#
# === [Epoch 21/300] ===
#  Batch 10/50: loss=-1.9616, reward=-237.9800, makespan=238.0
#  Batch 20/50: loss=-2.7210, reward=-239.5133, makespan=239.5
#  Batch 30/50: loss=-3.0866, reward=-239.2533, makespan=239.3
#  Batch 40/50: loss=-3.5138, reward=-241.4000, makespan=241.4
#  Batch 50/50: loss=-2.5614, reward=-238.6067, makespan=238.6
# [Epoch 21] => loss=-4.4081, reward=-236.5943, makespan=236.6
# [Epoch 21 학습 시간] : 38.79 초
#
# Evaluating...
# Evaluation 21 => makespan = 234.7699940999349
# Evaluation 21 평가 시간 : 4.65 초
#
# === [Epoch 22/300] ===
#  Batch 10/50: loss=-5.0392, reward=-243.6867, makespan=243.7
#  Batch 20/50: loss=-3.6980, reward=-236.8733, makespan=236.9
#  Batch 30/50: loss=-3.2407, reward=-244.6067, makespan=244.6
#  Batch 40/50: loss=0.5589, reward=-238.3067, makespan=238.3
#  Batch 50/50: loss=-4.2101, reward=-242.4533, makespan=242.5
# [Epoch 22] => loss=-3.7802, reward=-236.5908, makespan=236.6
# [Epoch 22 학습 시간] : 39.66 초
#
# Evaluating...
# Evaluation 22 => makespan = 232.5399958292643
# Evaluation 22 평가 시간 : 4.72 초
#
# === [Epoch 23/300] ===
#  Batch 10/50: loss=-1.8449, reward=-235.5800, makespan=235.6
#  Batch 20/50: loss=-2.9437, reward=-234.3200, makespan=234.3
#  Batch 30/50: loss=-4.6600, reward=-237.2467, makespan=237.2
#  Batch 40/50: loss=-0.3716, reward=-233.2267, makespan=233.2
#  Batch 50/50: loss=-4.9160, reward=-239.9000, makespan=239.9
# [Epoch 23] => loss=-3.8790, reward=-236.5492, makespan=236.5
# [Epoch 23 학습 시간] : 38.82 초
#
# Evaluating...
# Evaluation 23 => makespan = 233.63666407267252
# Evaluation 23 평가 시간 : 4.63 초
#
# === [Epoch 24/300] ===
#  Batch 10/50: loss=-4.2237, reward=-236.7267, makespan=236.7
#  Batch 20/50: loss=-5.9076, reward=-238.3333, makespan=238.3
#  Batch 30/50: loss=-8.6367, reward=-238.2933, makespan=238.3
#  Batch 40/50: loss=-4.2029, reward=-235.7533, makespan=235.8
#  Batch 50/50: loss=-2.8415, reward=-237.8600, makespan=237.9
# [Epoch 24] => loss=-3.7675, reward=-236.7756, makespan=236.8
# [Epoch 24 학습 시간] : 38.28 초
#
# Evaluating...
# Evaluation 24 => makespan = 230.98999659220377
# Evaluation 24 평가 시간 : 4.68 초
#
# === [Epoch 25/300] ===
#  Batch 10/50: loss=-1.3996, reward=-240.9067, makespan=240.9
#  Batch 20/50: loss=-4.4394, reward=-237.3267, makespan=237.3
#  Batch 30/50: loss=-6.7679, reward=-238.7000, makespan=238.7
#  Batch 40/50: loss=-4.0435, reward=-236.8400, makespan=236.8
#  Batch 50/50: loss=-1.8449, reward=-234.2533, makespan=234.3
# [Epoch 25] => loss=-3.5837, reward=-235.8771, makespan=235.9
# [Epoch 25 학습 시간] : 38.35 초
#
# Evaluating...
# Evaluation 25 => makespan = 232.49999364217123
# Evaluation 25 평가 시간 : 4.69 초
#
# === [Epoch 26/300] ===
#  Batch 10/50: loss=-4.0307, reward=-234.8800, makespan=234.9
#  Batch 20/50: loss=-2.0232, reward=-233.9400, makespan=233.9
#  Batch 30/50: loss=-4.0197, reward=-240.6067, makespan=240.6
#  Batch 40/50: loss=-2.1132, reward=-231.3133, makespan=231.3
#  Batch 50/50: loss=-4.3409, reward=-234.5800, makespan=234.6
# [Epoch 26] => loss=-3.6155, reward=-236.8637, makespan=236.9
# [Epoch 26 학습 시간] : 38.54 초
#
# Evaluating...
# Evaluation 26 => makespan = 232.65666325887045
# Evaluation 26 평가 시간 : 4.68 초
#
# === [Epoch 27/300] ===
#  Batch 10/50: loss=-5.4857, reward=-238.4733, makespan=238.5
#  Batch 20/50: loss=-4.8627, reward=-239.4133, makespan=239.4
#  Batch 30/50: loss=-2.5582, reward=-240.1000, makespan=240.1
#  Batch 40/50: loss=-4.6769, reward=-236.8267, makespan=236.8
#  Batch 50/50: loss=-3.1000, reward=-239.8000, makespan=239.8
# [Epoch 27] => loss=-3.8549, reward=-235.9689, makespan=236.0
# [Epoch 27 학습 시간] : 38.90 초
#
# Evaluating...
# Evaluation 27 => makespan = 234.12999216715494
# Evaluation 27 평가 시간 : 4.69 초
#
# === [Epoch 28/300] ===
#  Batch 10/50: loss=-4.0377, reward=-237.3400, makespan=237.3
#  Batch 20/50: loss=-5.6532, reward=-242.7933, makespan=242.8
#  Batch 30/50: loss=-3.6805, reward=-242.5333, makespan=242.5
#  Batch 40/50: loss=-0.7376, reward=-247.9867, makespan=248.0
#  Batch 50/50: loss=-3.1094, reward=-243.1000, makespan=243.1
# [Epoch 28] => loss=-3.6780, reward=-235.5109, makespan=235.5
# [Epoch 28 학습 시간] : 39.39 초
#
# Evaluating...
# Evaluation 28 => makespan = 234.53666305541992
# Evaluation 28 평가 시간 : 4.75 초
#
# === [Epoch 29/300] ===
#  Batch 10/50: loss=-2.9415, reward=-233.5867, makespan=233.6
#  Batch 20/50: loss=-4.8018, reward=-235.8467, makespan=235.8
#  Batch 30/50: loss=-3.9682, reward=-231.3133, makespan=231.3
#  Batch 40/50: loss=-1.2876, reward=-232.5133, makespan=232.5
#  Batch 50/50: loss=-2.6829, reward=-233.5067, makespan=233.5
# [Epoch 29] => loss=-3.0326, reward=-235.0307, makespan=235.0
# [Epoch 29 학습 시간] : 38.41 초
#
# Evaluating...
# Evaluation 29 => makespan = 235.4866625467936
# Evaluation 29 평가 시간 : 4.60 초
#
# === [Epoch 30/300] ===
#  Batch 10/50: loss=-4.1448, reward=-234.0333, makespan=234.0
#  Batch 20/50: loss=-2.3081, reward=-237.5000, makespan=237.5
#  Batch 30/50: loss=-2.2168, reward=-234.2800, makespan=234.3
#  Batch 40/50: loss=-0.9851, reward=-235.3733, makespan=235.4
#  Batch 50/50: loss=-3.8942, reward=-232.5733, makespan=232.6
# [Epoch 30] => loss=-3.3153, reward=-234.7473, makespan=234.7
# [Epoch 30 학습 시간] : 39.45 초
#
# Evaluating...
# Evaluation 30 => makespan = 232.7266616821289
# Evaluation 30 평가 시간 : 4.65 초
#
# === [Epoch 31/300] ===
#  Batch 10/50: loss=-1.8367, reward=-241.2667, makespan=241.3
#  Batch 20/50: loss=-3.4537, reward=-232.6333, makespan=232.6
#  Batch 30/50: loss=-2.8669, reward=-238.5200, makespan=238.5
#  Batch 40/50: loss=-1.8111, reward=-232.5867, makespan=232.6
#  Batch 50/50: loss=-2.9990, reward=-234.7267, makespan=234.7
# [Epoch 31] => loss=-2.8820, reward=-235.6255, makespan=235.6
# [Epoch 31 학습 시간] : 38.76 초
#
# Evaluating...
# Evaluation 31 => makespan = 232.69999567667642
# Evaluation 31 평가 시간 : 4.73 초
#
# === [Epoch 32/300] ===
#  Batch 10/50: loss=-3.7596, reward=-227.6200, makespan=227.6
#  Batch 20/50: loss=-1.9901, reward=-234.4000, makespan=234.4
#  Batch 30/50: loss=-2.0948, reward=-227.5400, makespan=227.5
#  Batch 40/50: loss=-3.7747, reward=-233.4867, makespan=233.5
#  Batch 50/50: loss=-4.9181, reward=-228.7667, makespan=228.8
# [Epoch 32] => loss=-2.9136, reward=-235.0836, makespan=235.1
# [Epoch 32 학습 시간] : 38.38 초
#
# Evaluating...
# Evaluation 32 => makespan = 234.44666290283203
# Evaluation 32 평가 시간 : 4.63 초
#
# === [Epoch 33/300] ===
#  Batch 10/50: loss=-4.2552, reward=-235.7533, makespan=235.8
#  Batch 20/50: loss=-4.5508, reward=-240.7800, makespan=240.8
#  Batch 30/50: loss=-3.1736, reward=-238.9867, makespan=239.0
#  Batch 40/50: loss=-5.5134, reward=-238.4467, makespan=238.4
#  Batch 50/50: loss=-2.4982, reward=-237.4467, makespan=237.4
# [Epoch 33] => loss=-3.1260, reward=-236.3771, makespan=236.4
# [Epoch 33 학습 시간] : 38.46 초
#
# Evaluating...
# Evaluation 33 => makespan = 235.54666137695312
# Evaluation 33 평가 시간 : 4.67 초
#
# === [Epoch 34/300] ===
#  Batch 10/50: loss=-3.7935, reward=-243.2933, makespan=243.3
#  Batch 20/50: loss=-2.4657, reward=-239.5867, makespan=239.6
#  Batch 30/50: loss=-5.4011, reward=-245.1800, makespan=245.2
#  Batch 40/50: loss=-3.1895, reward=-238.1400, makespan=238.1
#  Batch 50/50: loss=-4.7529, reward=-241.0000, makespan=241.0
# [Epoch 34] => loss=-2.7128, reward=-235.3515, makespan=235.4
# [Epoch 34 학습 시간] : 38.49 초
#
# Evaluating...
# Evaluation 34 => makespan = 232.80999374389648
# Evaluation 34 평가 시간 : 4.75 초
#
# === [Epoch 35/300] ===
#  Batch 10/50: loss=-3.1464, reward=-234.8600, makespan=234.9
#  Batch 20/50: loss=-3.2827, reward=-233.1600, makespan=233.2
#  Batch 30/50: loss=-2.3696, reward=-233.4533, makespan=233.5
#  Batch 40/50: loss=-5.2087, reward=-234.3133, makespan=234.3
#  Batch 50/50: loss=-3.5741, reward=-237.6933, makespan=237.7
# [Epoch 35] => loss=-3.5258, reward=-235.3640, makespan=235.4
# [Epoch 35 학습 시간] : 38.49 초
#
# Evaluating...
# Evaluation 35 => makespan = 231.55666224161783
# Evaluation 35 평가 시간 : 4.75 초
#
# === [Epoch 36/300] ===
#  Batch 10/50: loss=-2.0706, reward=-235.6933, makespan=235.7
#  Batch 20/50: loss=-3.3719, reward=-232.1067, makespan=232.1
#  Batch 30/50: loss=-2.6551, reward=-234.9533, makespan=235.0
#  Batch 40/50: loss=-2.4041, reward=-230.4933, makespan=230.5
#  Batch 50/50: loss=-0.7929, reward=-234.7533, makespan=234.8
# [Epoch 36] => loss=-3.1256, reward=-235.1841, makespan=235.2
# [Epoch 36 학습 시간] : 39.45 초
#
# Evaluating...
# Evaluation 36 => makespan = 231.82999420166016
# Evaluation 36 평가 시간 : 4.63 초
#
# === [Epoch 37/300] ===
#  Batch 10/50: loss=-3.6388, reward=-230.4133, makespan=230.4
#  Batch 20/50: loss=-3.1021, reward=-236.6600, makespan=236.7
#  Batch 30/50: loss=-2.0783, reward=-227.6000, makespan=227.6
#  Batch 40/50: loss=-2.0426, reward=-237.4133, makespan=237.4
#  Batch 50/50: loss=-3.2086, reward=-225.8000, makespan=225.8
# [Epoch 37] => loss=-3.2364, reward=-235.0788, makespan=235.1
# [Epoch 37 학습 시간] : 38.47 초
#
# Evaluating...
# Evaluation 37 => makespan = 231.30332819620767
# Evaluation 37 평가 시간 : 4.69 초
#
# === [Epoch 38/300] ===
#  Batch 10/50: loss=-5.2534, reward=-233.0933, makespan=233.1
#  Batch 20/50: loss=-4.3220, reward=-226.0067, makespan=226.0
#  Batch 30/50: loss=-2.7473, reward=-233.9800, makespan=234.0
#  Batch 40/50: loss=-2.8539, reward=-223.9133, makespan=223.9
#  Batch 50/50: loss=-3.4088, reward=-230.7067, makespan=230.7
# [Epoch 38] => loss=-2.6169, reward=-234.5484, makespan=234.5
# [Epoch 38 학습 시간] : 38.82 초
#
# Evaluating...
# Evaluation 38 => makespan = 230.68666330973306
# Evaluation 38 평가 시간 : 4.68 초
#
# === [Epoch 39/300] ===
#  Batch 10/50: loss=-1.1799, reward=-236.4000, makespan=236.4
#  Batch 20/50: loss=-0.4080, reward=-238.4667, makespan=238.5
#  Batch 30/50: loss=-1.8997, reward=-235.0400, makespan=235.0
#  Batch 40/50: loss=-0.5894, reward=-236.2200, makespan=236.2
#  Batch 50/50: loss=-2.6896, reward=-231.3600, makespan=231.4
# [Epoch 39] => loss=-2.9612, reward=-235.3172, makespan=235.3
# [Epoch 39 학습 시간] : 39.06 초
#
# Evaluating...
# Evaluation 39 => makespan = 233.5666618347168
# Evaluation 39 평가 시간 : 4.67 초
#
# === [Epoch 40/300] ===
#  Batch 10/50: loss=-4.1897, reward=-237.9400, makespan=237.9
#  Batch 20/50: loss=-1.7053, reward=-242.1600, makespan=242.2
#  Batch 30/50: loss=-3.8755, reward=-235.8067, makespan=235.8
#  Batch 40/50: loss=-1.0992, reward=-243.1800, makespan=243.2
#  Batch 50/50: loss=-6.1396, reward=-240.3467, makespan=240.3
# [Epoch 40] => loss=-2.6466, reward=-234.8445, makespan=234.8
# [Epoch 40 학습 시간] : 38.43 초
#
# Evaluating...
# Evaluation 40 => makespan = 233.85332743326822
# Evaluation 40 평가 시간 : 4.67 초
#
# === [Epoch 41/300] ===
#  Batch 10/50: loss=-2.8984, reward=-231.3867, makespan=231.4
#  Batch 20/50: loss=-1.7770, reward=-234.8000, makespan=234.8
#  Batch 30/50: loss=-2.1851, reward=-234.9333, makespan=234.9
#  Batch 40/50: loss=-2.7497, reward=-234.6133, makespan=234.6
#  Batch 50/50: loss=-2.8728, reward=-232.2400, makespan=232.2
# [Epoch 41] => loss=-2.8338, reward=-235.0112, makespan=235.0
# [Epoch 41 학습 시간] : 38.24 초
#
# Evaluating...
# Evaluation 41 => makespan = 232.9033292134603
# Evaluation 41 평가 시간 : 4.62 초
#
# === [Epoch 42/300] ===
#  Batch 10/50: loss=0.3290, reward=-229.4067, makespan=229.4
#  Batch 20/50: loss=-1.3923, reward=-233.9667, makespan=234.0
#  Batch 30/50: loss=-4.3322, reward=-229.9533, makespan=230.0
#  Batch 40/50: loss=-2.2993, reward=-236.1800, makespan=236.2
#  Batch 50/50: loss=-1.8955, reward=-229.9333, makespan=229.9
# [Epoch 42] => loss=-2.4031, reward=-234.2075, makespan=234.2
# [Epoch 42 학습 시간] : 38.19 초
#
# Evaluating...
# Evaluation 42 => makespan = 232.61666107177734
# Evaluation 42 평가 시간 : 4.69 초
#
# === [Epoch 43/300] ===
#  Batch 10/50: loss=-2.0898, reward=-235.6467, makespan=235.6
#  Batch 20/50: loss=-0.2507, reward=-226.2600, makespan=226.3
#  Batch 30/50: loss=-2.8440, reward=-235.2067, makespan=235.2
#  Batch 40/50: loss=-4.9800, reward=-227.4200, makespan=227.4
#  Batch 50/50: loss=-2.9964, reward=-232.9800, makespan=233.0
# [Epoch 43] => loss=-2.6776, reward=-234.0468, makespan=234.0
# [Epoch 43 학습 시간] : 38.68 초
#
# Evaluating...
# Evaluation 43 => makespan = 231.92332712809244
# Evaluation 43 평가 시간 : 4.73 초
#
# === [Epoch 44/300] ===
#  Batch 10/50: loss=-1.5722, reward=-226.4733, makespan=226.5
#  Batch 20/50: loss=-4.0755, reward=-231.8867, makespan=231.9
#  Batch 30/50: loss=-2.8467, reward=-227.3400, makespan=227.3
#  Batch 40/50: loss=-5.5792, reward=-234.1933, makespan=234.2
#  Batch 50/50: loss=-1.8978, reward=-224.1600, makespan=224.2
# [Epoch 44] => loss=-2.6696, reward=-234.8429, makespan=234.8
# [Epoch 44 학습 시간] : 39.39 초
#
# Evaluating...
# Evaluation 44 => makespan = 232.81999333699545
# Evaluation 44 평가 시간 : 4.76 초
#
# === [Epoch 45/300] ===
#  Batch 10/50: loss=-2.5744, reward=-238.4000, makespan=238.4
#  Batch 20/50: loss=-2.2854, reward=-231.6533, makespan=231.7
#  Batch 30/50: loss=-3.2916, reward=-236.3533, makespan=236.4
#  Batch 40/50: loss=-2.5775, reward=-232.2733, makespan=232.3
#  Batch 50/50: loss=-5.3589, reward=-234.2600, makespan=234.3
# [Epoch 45] => loss=-2.6037, reward=-234.1711, makespan=234.2
# [Epoch 45 학습 시간] : 38.83 초
#
# Evaluating...
# Evaluation 45 => makespan = 232.4266611735026
# Evaluation 45 평가 시간 : 4.60 초
#
# === [Epoch 46/300] ===
#  Batch 10/50: loss=-3.8941, reward=-243.6800, makespan=243.7
#  Batch 20/50: loss=-3.3388, reward=-233.5133, makespan=233.5
#  Batch 30/50: loss=-3.9810, reward=-236.5267, makespan=236.5
#  Batch 40/50: loss=-1.1682, reward=-231.7467, makespan=231.7
#  Batch 50/50: loss=-1.2460, reward=-234.4000, makespan=234.4
# [Epoch 46] => loss=-2.7649, reward=-233.3121, makespan=233.3
# [Epoch 46 학습 시간] : 38.52 초
#
# Evaluating...
# Evaluation 46 => makespan = 233.0399958292643
# Evaluation 46 평가 시간 : 4.75 초
#
# === [Epoch 47/300] ===
#  Batch 10/50: loss=-1.1655, reward=-237.0067, makespan=237.0
#  Batch 20/50: loss=-1.1828, reward=-232.8667, makespan=232.9
#  Batch 30/50: loss=-1.7574, reward=-234.4667, makespan=234.5
#  Batch 40/50: loss=-2.6989, reward=-229.9533, makespan=230.0
#  Batch 50/50: loss=0.1564, reward=-235.7267, makespan=235.7
# [Epoch 47] => loss=-2.2732, reward=-234.1383, makespan=234.1
# [Epoch 47 학습 시간] : 39.31 초
#
# Evaluating...
# Evaluation 47 => makespan = 231.28666178385416
# Evaluation 47 평가 시간 : 4.73 초
#
# === [Epoch 48/300] ===
#  Batch 10/50: loss=-0.1685, reward=-235.2333, makespan=235.2
#  Batch 20/50: loss=-0.6073, reward=-228.5600, makespan=228.6
#  Batch 30/50: loss=-2.0360, reward=-235.3067, makespan=235.3
#  Batch 40/50: loss=-4.2745, reward=-228.7733, makespan=228.8
#  Batch 50/50: loss=-4.0131, reward=-236.1933, makespan=236.2
# [Epoch 48] => loss=-2.5183, reward=-234.5335, makespan=234.5
# [Epoch 48 학습 시간] : 38.74 초
#
# Evaluating...
# Evaluation 48 => makespan = 231.61999384562174
# Evaluation 48 평가 시간 : 4.65 초
#
# === [Epoch 49/300] ===
#  Batch 10/50: loss=-4.0707, reward=-229.4067, makespan=229.4
#  Batch 20/50: loss=-3.9968, reward=-235.6600, makespan=235.7
#  Batch 30/50: loss=-2.4164, reward=-229.1000, makespan=229.1
#  Batch 40/50: loss=-0.9691, reward=-236.7800, makespan=236.8
#  Batch 50/50: loss=-2.4290, reward=-227.1400, makespan=227.1
# [Epoch 49] => loss=-2.1462, reward=-234.7373, makespan=234.7
# [Epoch 49 학습 시간] : 38.33 초
#
# Evaluating...
# Evaluation 49 => makespan = 230.30666224161783
# Evaluation 49 평가 시간 : 4.70 초
#
# === [Epoch 50/300] ===
#  Batch 10/50: loss=-3.3799, reward=-235.4600, makespan=235.5
#  Batch 20/50: loss=-3.9104, reward=-224.5800, makespan=224.6
#  Batch 30/50: loss=-3.6213, reward=-235.6533, makespan=235.7
#  Batch 40/50: loss=-2.4347, reward=-229.2667, makespan=229.3
#  Batch 50/50: loss=-2.0274, reward=-240.2200, makespan=240.2
# [Epoch 50] => loss=-2.0316, reward=-234.3960, makespan=234.4
# [Epoch 50 학습 시간] : 38.56 초
#
# Evaluating...
# Evaluation 50 => makespan = 229.53332901000977
# Evaluation 50 평가 시간 : 4.63 초
#
# === [Epoch 51/300] ===
#  Batch 10/50: loss=-3.0051, reward=-228.7267, makespan=228.7
#  Batch 20/50: loss=-1.4736, reward=-234.9800, makespan=235.0
#  Batch 30/50: loss=-1.9564, reward=-226.3067, makespan=226.3
#  Batch 40/50: loss=-1.0983, reward=-238.9600, makespan=239.0
#  Batch 50/50: loss=-4.3522, reward=-227.8467, makespan=227.8
# [Epoch 51] => loss=-2.4228, reward=-234.0515, makespan=234.1
# [Epoch 51 학습 시간] : 38.61 초
#
# Evaluating...
# Evaluation 51 => makespan = 233.73999659220377
# Evaluation 51 평가 시간 : 4.68 초
#
# === [Epoch 52/300] ===
#  Batch 10/50: loss=-3.1072, reward=-231.2333, makespan=231.2
#  Batch 20/50: loss=-0.5877, reward=-238.0533, makespan=238.1
#  Batch 30/50: loss=-1.8772, reward=-232.9667, makespan=233.0
#  Batch 40/50: loss=-0.3488, reward=-236.4200, makespan=236.4
#  Batch 50/50: loss=-1.3878, reward=-233.2533, makespan=233.3
# [Epoch 52] => loss=-2.1357, reward=-234.6172, makespan=234.6
# [Epoch 52 학습 시간] : 38.87 초
#
# Evaluating...
# Evaluation 52 => makespan = 233.40999603271484
# Evaluation 52 평가 시간 : 4.66 초
#
# === [Epoch 53/300] ===
#  Batch 10/50: loss=0.4818, reward=-233.4200, makespan=233.4
#  Batch 20/50: loss=-1.1744, reward=-235.3733, makespan=235.4
#  Batch 30/50: loss=-2.8379, reward=-234.3667, makespan=234.4
#  Batch 40/50: loss=-2.2100, reward=-237.4867, makespan=237.5
#  Batch 50/50: loss=-2.5382, reward=-231.6333, makespan=231.6
# [Epoch 53] => loss=-2.3288, reward=-233.7109, makespan=233.7
# [Epoch 53 학습 시간] : 38.93 초
#
# Evaluating...
# Evaluation 53 => makespan = 232.06666056315103
# Evaluation 53 평가 시간 : 4.68 초
#
# === [Epoch 54/300] ===
#  Batch 10/50: loss=-0.9141, reward=-226.4133, makespan=226.4
#  Batch 20/50: loss=-4.7029, reward=-234.4533, makespan=234.5
#  Batch 30/50: loss=-2.4420, reward=-228.6267, makespan=228.6
#  Batch 40/50: loss=-5.3774, reward=-234.5733, makespan=234.6
#  Batch 50/50: loss=-2.3007, reward=-229.3267, makespan=229.3
# [Epoch 54] => loss=-2.1931, reward=-233.6753, makespan=233.7
# [Epoch 54 학습 시간] : 38.34 초
#
# Evaluating...
# Evaluation 54 => makespan = 231.4366594950358
# Evaluation 54 평가 시간 : 4.60 초
#
# === [Epoch 55/300] ===
#  Batch 10/50: loss=-2.7522, reward=-234.6933, makespan=234.7
#  Batch 20/50: loss=-1.5495, reward=-228.5867, makespan=228.6
#  Batch 30/50: loss=-3.6342, reward=-234.4333, makespan=234.4
#  Batch 40/50: loss=-1.1203, reward=-229.5467, makespan=229.5
#  Batch 50/50: loss=-2.1662, reward=-231.0067, makespan=231.0
# [Epoch 55] => loss=-2.3512, reward=-232.6852, makespan=232.7
# [Epoch 55 학습 시간] : 39.10 초
#
# Evaluating...
# Evaluation 55 => makespan = 232.50332895914713
# Evaluation 55 평가 시간 : 4.70 초
#
# === [Epoch 56/300] ===
#  Batch 10/50: loss=-2.3978, reward=-228.2600, makespan=228.3
#  Batch 20/50: loss=-3.5639, reward=-238.8667, makespan=238.9
#  Batch 30/50: loss=-3.3708, reward=-229.8800, makespan=229.9
#  Batch 40/50: loss=-1.4153, reward=-239.2733, makespan=239.3
#  Batch 50/50: loss=-1.5390, reward=-232.3867, makespan=232.4
# [Epoch 56] => loss=-2.2514, reward=-233.7623, makespan=233.8
# [Epoch 56 학습 시간] : 38.67 초
#
# Evaluating...
# Evaluation 56 => makespan = 236.92999394734701
# Evaluation 56 평가 시간 : 4.73 초
#
# === [Epoch 57/300] ===
#  Batch 10/50: loss=0.9789, reward=-235.0867, makespan=235.1
#  Batch 20/50: loss=-1.7231, reward=-224.5933, makespan=224.6
#  Batch 30/50: loss=-1.5114, reward=-236.6467, makespan=236.6
#  Batch 40/50: loss=-3.9176, reward=-226.3933, makespan=226.4
#  Batch 50/50: loss=-4.3142, reward=-236.3333, makespan=236.3
# [Epoch 57] => loss=-2.2043, reward=-233.0269, makespan=233.0
# [Epoch 57 학습 시간] : 38.37 초
#
# Evaluating...
# Evaluation 57 => makespan = 231.1733283996582
# Evaluation 57 평가 시간 : 4.61 초
#
# === [Epoch 58/300] ===
#  Batch 10/50: loss=-2.1165, reward=-233.7000, makespan=233.7
#  Batch 20/50: loss=-2.8899, reward=-229.6867, makespan=229.7
#  Batch 30/50: loss=-2.2835, reward=-234.3667, makespan=234.4
#  Batch 40/50: loss=-1.6219, reward=-230.0267, makespan=230.0
#  Batch 50/50: loss=-3.2719, reward=-232.0533, makespan=232.1
# [Epoch 58] => loss=-2.3103, reward=-232.6808, makespan=232.7
# [Epoch 58 학습 시간] : 38.16 초
#
# Evaluating...
# Evaluation 58 => makespan = 232.14666239420572
# Evaluation 58 평가 시간 : 4.70 초
#
# === [Epoch 59/300] ===
#  Batch 10/50: loss=-1.7314, reward=-238.7800, makespan=238.8
#  Batch 20/50: loss=-1.8382, reward=-235.5867, makespan=235.6
#  Batch 30/50: loss=-3.6789, reward=-239.3467, makespan=239.3
#  Batch 40/50: loss=-3.1398, reward=-232.7333, makespan=232.7
#  Batch 50/50: loss=-0.6176, reward=-240.1800, makespan=240.2
# [Epoch 59] => loss=-2.4104, reward=-233.1924, makespan=233.2
# [Epoch 59 학습 시간] : 38.14 초
#
# Evaluating...
# Evaluation 59 => makespan = 229.27666219075522
# Evaluation 59 평가 시간 : 4.62 초
#
# === [Epoch 60/300] ===
#  Batch 10/50: loss=-3.3089, reward=-233.8867, makespan=233.9
#  Batch 20/50: loss=-2.5280, reward=-228.6600, makespan=228.7
#  Batch 30/50: loss=-4.5726, reward=-232.8133, makespan=232.8
#  Batch 40/50: loss=-2.3960, reward=-227.7533, makespan=227.8
#  Batch 50/50: loss=-2.4988, reward=-233.6600, makespan=233.7
# [Epoch 60] => loss=-2.2134, reward=-233.4933, makespan=233.5
# [Epoch 60 학습 시간] : 38.35 초
#
# Evaluating...
# Evaluation 60 => makespan = 229.97999572753906
# Evaluation 60 평가 시간 : 4.72 초
#
# === [Epoch 61/300] ===
#  Batch 10/50: loss=-1.1333, reward=-226.9800, makespan=227.0
#  Batch 20/50: loss=-2.0336, reward=-230.7067, makespan=230.7
#  Batch 30/50: loss=-6.0630, reward=-229.0133, makespan=229.0
#  Batch 40/50: loss=-2.0598, reward=-231.6267, makespan=231.6
#  Batch 50/50: loss=-2.6938, reward=-229.1933, makespan=229.2
# [Epoch 61] => loss=-2.3208, reward=-232.9808, makespan=233.0
# [Epoch 61 학습 시간] : 39.04 초
#
# Evaluating...
# Evaluation 61 => makespan = 228.92665990193686
# Evaluation 61 평가 시간 : 4.74 초
#
# === [Epoch 62/300] ===
#  Batch 10/50: loss=-1.8746, reward=-240.6733, makespan=240.7
#  Batch 20/50: loss=-1.9928, reward=-229.6133, makespan=229.6
#  Batch 30/50: loss=-3.3799, reward=-241.3533, makespan=241.4
#  Batch 40/50: loss=-2.5627, reward=-231.7533, makespan=231.8
#  Batch 50/50: loss=-0.5626, reward=-238.8067, makespan=238.8
# [Epoch 62] => loss=-2.0611, reward=-233.2876, makespan=233.3
# [Epoch 62 학습 시간] : 38.31 초
#
# Evaluating...
# Evaluation 62 => makespan = 229.94666163126627
# Evaluation 62 평가 시간 : 4.67 초
#
# === [Epoch 63/300] ===
#  Batch 10/50: loss=1.4015, reward=-228.9067, makespan=228.9
#  Batch 20/50: loss=-3.3882, reward=-235.0933, makespan=235.1
#  Batch 30/50: loss=-4.1380, reward=-228.8733, makespan=228.9
#  Batch 40/50: loss=-0.9860, reward=-231.0000, makespan=231.0
#  Batch 50/50: loss=-1.9926, reward=-228.7200, makespan=228.7
# [Epoch 63] => loss=-1.9594, reward=-232.9956, makespan=233.0
# [Epoch 63 학습 시간] : 38.80 초
#
# Evaluating...
# Evaluation 63 => makespan = 230.69999313354492
# Evaluation 63 평가 시간 : 4.66 초
#
# === [Epoch 64/300] ===
#  Batch 10/50: loss=-0.1101, reward=-233.1533, makespan=233.2
#  Batch 20/50: loss=-0.0843, reward=-232.0733, makespan=232.1
#  Batch 30/50: loss=-1.1626, reward=-231.8933, makespan=231.9
#  Batch 40/50: loss=-0.6968, reward=-233.1333, makespan=233.1
#  Batch 50/50: loss=-1.0547, reward=-233.6867, makespan=233.7
# [Epoch 64] => loss=-2.0084, reward=-232.5853, makespan=232.6
# [Epoch 64 학습 시간] : 38.85 초
#
# Evaluating...
# Evaluation 64 => makespan = 231.4933293660482
# Evaluation 64 평가 시간 : 4.76 초
#
# === [Epoch 65/300] ===
#  Batch 10/50: loss=-3.7327, reward=-232.9267, makespan=232.9
#  Batch 20/50: loss=-2.4334, reward=-242.9733, makespan=243.0
#  Batch 30/50: loss=-3.4041, reward=-235.5333, makespan=235.5
#  Batch 40/50: loss=-1.1808, reward=-236.9267, makespan=236.9
#  Batch 50/50: loss=-3.1069, reward=-234.6200, makespan=234.6
# [Epoch 65] => loss=-2.2475, reward=-232.4532, makespan=232.5
# [Epoch 65 학습 시간] : 38.43 초
#
# Evaluating...
# Evaluation 65 => makespan = 231.47332890828451
# Evaluation 65 평가 시간 : 4.70 초
#
# === [Epoch 66/300] ===
#  Batch 10/50: loss=-2.3472, reward=-227.8467, makespan=227.8
#  Batch 20/50: loss=-2.6340, reward=-232.8067, makespan=232.8
#  Batch 30/50: loss=0.9518, reward=-229.8267, makespan=229.8
#  Batch 40/50: loss=-2.4316, reward=-234.1400, makespan=234.1
#  Batch 50/50: loss=-3.4661, reward=-229.5400, makespan=229.5
# [Epoch 66] => loss=-2.1800, reward=-232.2217, makespan=232.2
# [Epoch 66 학습 시간] : 38.23 초
#
# Evaluating...
# Evaluation 66 => makespan = 230.67999394734701
# Evaluation 66 평가 시간 : 4.61 초
#
# === [Epoch 67/300] ===
#  Batch 10/50: loss=-3.0145, reward=-233.7733, makespan=233.8
#  Batch 20/50: loss=-1.3081, reward=-230.4467, makespan=230.4
#  Batch 30/50: loss=-1.6220, reward=-233.6467, makespan=233.6
#  Batch 40/50: loss=-2.7393, reward=-234.3000, makespan=234.3
#  Batch 50/50: loss=-2.4429, reward=-230.5933, makespan=230.6
# [Epoch 67] => loss=-2.1066, reward=-231.8375, makespan=231.8
# [Epoch 67 학습 시간] : 38.11 초
#
# Evaluating...
# Evaluation 67 => makespan = 230.85666147867838
# Evaluation 67 평가 시간 : 4.77 초
#
# === [Epoch 68/300] ===
#  Batch 10/50: loss=-3.9200, reward=-229.5600, makespan=229.6
#  Batch 20/50: loss=-3.5414, reward=-236.4067, makespan=236.4
#  Batch 30/50: loss=-1.2139, reward=-232.8533, makespan=232.9
#  Batch 40/50: loss=-2.6000, reward=-234.5133, makespan=234.5
#  Batch 50/50: loss=-3.0761, reward=-232.9933, makespan=233.0
# [Epoch 68] => loss=-2.1726, reward=-232.0236, makespan=232.0
# [Epoch 68 학습 시간] : 38.09 초
#
# Evaluating...
# Evaluation 68 => makespan = 230.47332890828451
# Evaluation 68 평가 시간 : 4.67 초
#
# === [Epoch 69/300] ===
#  Batch 10/50: loss=-3.5910, reward=-231.6867, makespan=231.7
#  Batch 20/50: loss=-0.4703, reward=-229.6933, makespan=229.7
#  Batch 30/50: loss=-1.4810, reward=-230.1000, makespan=230.1
#  Batch 40/50: loss=-2.2291, reward=-228.4867, makespan=228.5
#  Batch 50/50: loss=-3.2319, reward=-225.8933, makespan=225.9
# [Epoch 69] => loss=-1.8778, reward=-231.8927, makespan=231.9
# [Epoch 69 학습 시간] : 39.03 초
#
# Evaluating...
# Evaluation 69 => makespan = 230.73999404907227
# Evaluation 69 평가 시간 : 4.69 초
#
# === [Epoch 70/300] ===
#  Batch 10/50: loss=-2.5192, reward=-236.0333, makespan=236.0
#  Batch 20/50: loss=0.0881, reward=-234.2333, makespan=234.2
#  Batch 30/50: loss=-1.1680, reward=-233.5400, makespan=233.5
#  Batch 40/50: loss=-2.2911, reward=-235.2600, makespan=235.3
#  Batch 50/50: loss=-0.7264, reward=-236.0400, makespan=236.0
# [Epoch 70] => loss=-2.2558, reward=-231.6764, makespan=231.7
# [Epoch 70 학습 시간] : 38.59 초
#
# Evaluating...
# Evaluation 70 => makespan = 232.19999567667642
# Evaluation 70 평가 시간 : 4.66 초
#
# === [Epoch 71/300] ===
#  Batch 10/50: loss=-1.7847, reward=-242.6667, makespan=242.7
#  Batch 20/50: loss=-4.4923, reward=-236.3333, makespan=236.3
#  Batch 30/50: loss=-1.2126, reward=-244.0933, makespan=244.1
#  Batch 40/50: loss=-2.5591, reward=-242.4467, makespan=242.4
#  Batch 50/50: loss=-1.1527, reward=-245.3733, makespan=245.4
# [Epoch 71] => loss=-1.6201, reward=-233.9061, makespan=233.9
# [Epoch 71 학습 시간] : 38.84 초
#
# Evaluating...
# Evaluation 71 => makespan = 231.85666147867838
# Evaluation 71 평가 시간 : 4.86 초
#
# === [Epoch 72/300] ===
#  Batch 10/50: loss=-0.6209, reward=-237.2933, makespan=237.3
#  Batch 20/50: loss=-0.7205, reward=-231.1000, makespan=231.1
#  Batch 30/50: loss=-3.2266, reward=-238.1267, makespan=238.1
#  Batch 40/50: loss=-1.5431, reward=-231.2133, makespan=231.2
#  Batch 50/50: loss=-0.5243, reward=-230.3533, makespan=230.4
# [Epoch 72] => loss=-1.8570, reward=-233.5989, makespan=233.6
# [Epoch 72 학습 시간] : 39.17 초
#
# Evaluating...
# Evaluation 72 => makespan = 231.43999608357748
# Evaluation 72 평가 시간 : 4.65 초
#
# === [Epoch 73/300] ===
#  Batch 10/50: loss=-1.0016, reward=-236.5933, makespan=236.6
#  Batch 20/50: loss=-2.0722, reward=-230.7733, makespan=230.8
#  Batch 30/50: loss=-3.8454, reward=-235.3800, makespan=235.4
#  Batch 40/50: loss=-0.6478, reward=-230.2933, makespan=230.3
#  Batch 50/50: loss=-4.2259, reward=-234.0933, makespan=234.1
# [Epoch 73] => loss=-1.8865, reward=-232.8337, makespan=232.8
# [Epoch 73 학습 시간] : 38.83 초
#
# Evaluating...
# Evaluation 73 => makespan = 229.80665969848633
# Evaluation 73 평가 시간 : 4.61 초
#
# === [Epoch 74/300] ===
#  Batch 10/50: loss=-2.4356, reward=-234.2867, makespan=234.3
#  Batch 20/50: loss=0.2563, reward=-234.4200, makespan=234.4
#  Batch 30/50: loss=-2.0069, reward=-233.2667, makespan=233.3
#  Batch 40/50: loss=-2.5557, reward=-235.8133, makespan=235.8
#  Batch 50/50: loss=-3.3498, reward=-230.2733, makespan=230.3
# [Epoch 74] => loss=-1.9310, reward=-232.6988, makespan=232.7
# [Epoch 74 학습 시간] : 38.48 초
#
# Evaluating...
# Evaluation 74 => makespan = 230.6566619873047
# Evaluation 74 평가 시간 : 4.65 초
#
# === [Epoch 75/300] ===
#  Batch 10/50: loss=-1.0865, reward=-230.7133, makespan=230.7
#  Batch 20/50: loss=-1.4201, reward=-226.4267, makespan=226.4
#  Batch 30/50: loss=-0.3141, reward=-234.1933, makespan=234.2
#  Batch 40/50: loss=-3.9484, reward=-227.2400, makespan=227.2
#  Batch 50/50: loss=-2.5672, reward=-232.9267, makespan=232.9
# [Epoch 75] => loss=-1.7297, reward=-233.6992, makespan=233.7
# [Epoch 75 학습 시간] : 38.36 초
#
# Evaluating...
# Evaluation 75 => makespan = 231.37332661946616
# Evaluation 75 평가 시간 : 4.62 초
#
# === [Epoch 76/300] ===
#  Batch 10/50: loss=-1.3291, reward=-237.5800, makespan=237.6
#  Batch 20/50: loss=-1.1898, reward=-235.7200, makespan=235.7
#  Batch 30/50: loss=-2.6920, reward=-238.7667, makespan=238.8
#  Batch 40/50: loss=-2.7789, reward=-236.8667, makespan=236.9
#  Batch 50/50: loss=-2.2112, reward=-234.0600, makespan=234.1
# [Epoch 76] => loss=-1.9814, reward=-232.4540, makespan=232.5
# [Epoch 76 학습 시간] : 38.48 초
#
# Evaluating...
# Evaluation 76 => makespan = 230.3166618347168
# Evaluation 76 평가 시간 : 4.67 초
#
# === [Epoch 77/300] ===
#  Batch 10/50: loss=-1.4157, reward=-237.5533, makespan=237.6
#  Batch 20/50: loss=-0.6172, reward=-242.6533, makespan=242.7
#  Batch 30/50: loss=-1.3755, reward=-238.7600, makespan=238.8
#  Batch 40/50: loss=-1.3829, reward=-242.8733, makespan=242.9
#  Batch 50/50: loss=-1.2137, reward=-236.7067, makespan=236.7
# [Epoch 77] => loss=-2.1407, reward=-231.6168, makespan=231.6
# [Epoch 77 학습 시간] : 38.89 초
#
# Evaluating...
# Evaluation 77 => makespan = 229.43332799275717
# Evaluation 77 평가 시간 : 4.75 초
#
# === [Epoch 78/300] ===
#  Batch 10/50: loss=-0.3945, reward=-227.2067, makespan=227.2
#  Batch 20/50: loss=-0.6286, reward=-229.4867, makespan=229.5
#  Batch 30/50: loss=-0.4450, reward=-227.7467, makespan=227.7
#  Batch 40/50: loss=-0.8570, reward=-231.5267, makespan=231.5
#  Batch 50/50: loss=-4.4128, reward=-230.9400, makespan=230.9
# [Epoch 78] => loss=-1.6852, reward=-232.0976, makespan=232.1
# [Epoch 78 학습 시간] : 38.87 초
#
# Evaluating...
# Evaluation 78 => makespan = 230.33332697550455
# Evaluation 78 평가 시간 : 4.68 초
#
# === [Epoch 79/300] ===
#  Batch 10/50: loss=-3.0842, reward=-230.4200, makespan=230.4
#  Batch 20/50: loss=-1.9123, reward=-233.0667, makespan=233.1
#  Batch 30/50: loss=-0.2199, reward=-238.5600, makespan=238.6
#  Batch 40/50: loss=-0.6271, reward=-235.7200, makespan=235.7
#  Batch 50/50: loss=-1.4283, reward=-227.1467, makespan=227.1
# [Epoch 79] => loss=-1.5728, reward=-232.8163, makespan=232.8
# [Epoch 79 학습 시간] : 38.48 초
#
# Evaluating...
# Evaluation 79 => makespan = 230.63666025797525
# Evaluation 79 평가 시간 : 4.66 초
#
# === [Epoch 80/300] ===
#  Batch 10/50: loss=-3.2699, reward=-230.6200, makespan=230.6
#  Batch 20/50: loss=-1.7289, reward=-229.7067, makespan=229.7
#  Batch 30/50: loss=-3.0151, reward=-230.7800, makespan=230.8
#  Batch 40/50: loss=-1.2577, reward=-225.5867, makespan=225.6
#  Batch 50/50: loss=-4.1206, reward=-232.3333, makespan=232.3
# [Epoch 80] => loss=-1.8998, reward=-231.8203, makespan=231.8
# [Epoch 80 학습 시간] : 39.19 초
#
# Evaluating...
# Evaluation 80 => makespan = 230.6933275858561
# Evaluation 80 평가 시간 : 4.73 초
#
# === [Epoch 81/300] ===
#  Batch 10/50: loss=-1.3459, reward=-223.7067, makespan=223.7
#  Batch 20/50: loss=-0.5974, reward=-229.1800, makespan=229.2
#  Batch 30/50: loss=-4.5427, reward=-225.3933, makespan=225.4
#  Batch 40/50: loss=-2.5680, reward=-227.2133, makespan=227.2
#  Batch 50/50: loss=-3.3246, reward=-222.9600, makespan=223.0
# [Epoch 81] => loss=-1.6575, reward=-231.8756, makespan=231.9
# [Epoch 81 학습 시간] : 38.86 초
#
# Evaluating...
# Evaluation 81 => makespan = 231.79999542236328
# Evaluation 81 평가 시간 : 4.65 초
#
# === [Epoch 82/300] ===
#  Batch 10/50: loss=-1.3036, reward=-235.9067, makespan=235.9
#  Batch 20/50: loss=-1.3831, reward=-234.1200, makespan=234.1
#  Batch 30/50: loss=-2.0411, reward=-235.5733, makespan=235.6
#  Batch 40/50: loss=-1.6871, reward=-233.6067, makespan=233.6
#  Batch 50/50: loss=-1.4590, reward=-234.9400, makespan=234.9
# [Epoch 82] => loss=-1.4233, reward=-231.3099, makespan=231.3
# [Epoch 82 학습 시간] : 38.42 초
#
# Evaluating...
# Evaluation 82 => makespan = 231.48999659220377
# Evaluation 82 평가 시간 : 4.64 초
#
# === [Epoch 83/300] ===
#  Batch 10/50: loss=-3.0155, reward=-242.3867, makespan=242.4
#  Batch 20/50: loss=0.4906, reward=-235.5800, makespan=235.6
#  Batch 30/50: loss=1.1404, reward=-241.8933, makespan=241.9
#  Batch 40/50: loss=-2.2204, reward=-235.7333, makespan=235.7
#  Batch 50/50: loss=-1.1929, reward=-238.9933, makespan=239.0
# [Epoch 83] => loss=-1.8813, reward=-231.4480, makespan=231.4
# [Epoch 83 학습 시간] : 38.45 초
#
# Evaluating...
# Evaluation 83 => makespan = 230.45332972208658
# Evaluation 83 평가 시간 : 4.68 초
#
# === [Epoch 84/300] ===
#  Batch 10/50: loss=-1.2215, reward=-233.1667, makespan=233.2
#  Batch 20/50: loss=-1.8828, reward=-228.4867, makespan=228.5
#  Batch 30/50: loss=-0.7421, reward=-234.0933, makespan=234.1
#  Batch 40/50: loss=-1.7797, reward=-231.4333, makespan=231.4
#  Batch 50/50: loss=0.7516, reward=-233.8600, makespan=233.9
# [Epoch 84] => loss=-1.7838, reward=-231.5703, makespan=231.6
# [Epoch 84 학습 시간] : 38.45 초
#
# Evaluating...
# Evaluation 84 => makespan = 229.05332819620767
# Evaluation 84 평가 시간 : 4.63 초
#
# === [Epoch 85/300] ===
#  Batch 10/50: loss=-1.2488, reward=-232.9933, makespan=233.0
#  Batch 20/50: loss=-1.1027, reward=-226.4467, makespan=226.4
#  Batch 30/50: loss=-0.7628, reward=-232.8400, makespan=232.8
#  Batch 40/50: loss=-2.2275, reward=-229.9867, makespan=230.0
#  Batch 50/50: loss=-1.9764, reward=-231.9000, makespan=231.9
# [Epoch 85] => loss=-2.0127, reward=-231.9887, makespan=232.0
# [Epoch 85 학습 시간] : 38.69 초
#
# Evaluating...
# Evaluation 85 => makespan = 228.71332550048828
# Evaluation 85 평가 시간 : 4.90 초
#
# === [Epoch 86/300] ===
#  Batch 10/50: loss=-0.4676, reward=-223.6667, makespan=223.7
#  Batch 20/50: loss=-2.7162, reward=-233.4333, makespan=233.4
#  Batch 30/50: loss=-1.0028, reward=-223.4867, makespan=223.5
#  Batch 40/50: loss=-0.1182, reward=-231.5800, makespan=231.6
#  Batch 50/50: loss=-0.5001, reward=-224.4667, makespan=224.5
# [Epoch 86] => loss=-1.4924, reward=-231.8235, makespan=231.8
# [Epoch 86 학습 시간] : 39.32 초
#
# Evaluating...
# Evaluation 86 => makespan = 229.3199946085612
# Evaluation 86 평가 시간 : 4.72 초
#
# === [Epoch 87/300] ===
#  Batch 10/50: loss=-0.8372, reward=-229.2600, makespan=229.3
#  Batch 20/50: loss=-2.7158, reward=-222.6333, makespan=222.6
#  Batch 30/50: loss=-1.3842, reward=-228.6067, makespan=228.6
#  Batch 40/50: loss=-2.2933, reward=-217.9133, makespan=217.9
#  Batch 50/50: loss=-0.7356, reward=-230.4600, makespan=230.5
# [Epoch 87] => loss=-1.6926, reward=-231.8165, makespan=231.8
# [Epoch 87 학습 시간] : 38.47 초
#
# Evaluating...
# Evaluation 87 => makespan = 228.07666142781576
# Evaluation 87 평가 시간 : 4.66 초
#
# === [Epoch 88/300] ===
#  Batch 10/50: loss=1.2578, reward=-233.3933, makespan=233.4
#  Batch 20/50: loss=-1.8641, reward=-237.5067, makespan=237.5
#  Batch 30/50: loss=-3.8746, reward=-226.0333, makespan=226.0
#  Batch 40/50: loss=-0.8078, reward=-235.7467, makespan=235.7
#  Batch 50/50: loss=-2.0121, reward=-226.0933, makespan=226.1
# [Epoch 88] => loss=-1.7169, reward=-231.5748, makespan=231.6
# [Epoch 88 학습 시간] : 39.08 초
#
# Evaluating...
# Evaluation 88 => makespan = 229.1833292643229
# Evaluation 88 평가 시간 : 4.75 초
#
# === [Epoch 89/300] ===
#  Batch 10/50: loss=-2.2079, reward=-233.2067, makespan=233.2
#  Batch 20/50: loss=-1.5110, reward=-239.0933, makespan=239.1
#  Batch 30/50: loss=-0.8664, reward=-231.4400, makespan=231.4
#  Batch 40/50: loss=-1.5395, reward=-237.9533, makespan=238.0
#  Batch 50/50: loss=-1.8901, reward=-231.7933, makespan=231.8
# [Epoch 89] => loss=-1.7074, reward=-231.2660, makespan=231.3
# [Epoch 89 학습 시간] : 38.79 초
#
# Evaluating...
# Evaluation 89 => makespan = 229.7166608174642
# Evaluation 89 평가 시간 : 4.79 초
#
# === [Epoch 90/300] ===
#  Batch 10/50: loss=-1.7345, reward=-231.9933, makespan=232.0
#  Batch 20/50: loss=-4.3034, reward=-231.7867, makespan=231.8
#  Batch 30/50: loss=-1.2433, reward=-228.1933, makespan=228.2
#  Batch 40/50: loss=1.0644, reward=-228.3200, makespan=228.3
#  Batch 50/50: loss=-1.8349, reward=-228.0800, makespan=228.1
# [Epoch 90] => loss=-1.6744, reward=-231.1016, makespan=231.1
# [Epoch 90 학습 시간] : 38.52 초
#
# Evaluating...
# Evaluation 90 => makespan = 230.14332834879556
# Evaluation 90 평가 시간 : 4.60 초
#
# === [Epoch 91/300] ===
#  Batch 10/50: loss=-1.4040, reward=-228.1667, makespan=228.2
#  Batch 20/50: loss=-0.7655, reward=-231.3467, makespan=231.3
#  Batch 30/50: loss=-1.4365, reward=-227.0133, makespan=227.0
#  Batch 40/50: loss=-2.4814, reward=-233.9000, makespan=233.9
#  Batch 50/50: loss=-3.5301, reward=-226.9533, makespan=227.0
# [Epoch 91] => loss=-1.7453, reward=-230.9361, makespan=230.9
# [Epoch 91 학습 시간] : 38.40 초
#
# Evaluating...
# Evaluation 91 => makespan = 230.47332890828451
# Evaluation 91 평가 시간 : 4.67 초
#
# === [Epoch 92/300] ===
#  Batch 10/50: loss=-1.2436, reward=-234.4133, makespan=234.4
#  Batch 20/50: loss=-1.1454, reward=-224.9267, makespan=224.9
#  Batch 30/50: loss=-1.4550, reward=-231.6000, makespan=231.6
#  Batch 40/50: loss=-3.0726, reward=-223.4867, makespan=223.5
#  Batch 50/50: loss=-2.4962, reward=-236.7333, makespan=236.7
# [Epoch 92] => loss=-1.6187, reward=-231.9765, makespan=232.0
# [Epoch 92 학습 시간] : 38.04 초
#
# Evaluating...
# Evaluation 92 => makespan = 234.36332829793295
# Evaluation 92 평가 시간 : 4.78 초
#
# === [Epoch 93/300] ===
#  Batch 10/50: loss=-2.6414, reward=-223.4867, makespan=223.5
#  Batch 20/50: loss=-1.3889, reward=-233.3600, makespan=233.4
#  Batch 30/50: loss=-2.7825, reward=-220.3667, makespan=220.4
#  Batch 40/50: loss=-0.7836, reward=-234.2267, makespan=234.2
#  Batch 50/50: loss=-1.4645, reward=-228.5400, makespan=228.5
# [Epoch 93] => loss=-1.2913, reward=-231.6793, makespan=231.7
# [Epoch 93 학습 시간] : 38.24 초
#
# Evaluating...
# Evaluation 93 => makespan = 233.2466608683268
# Evaluation 93 평가 시간 : 4.65 초
#
# === [Epoch 94/300] ===
#  Batch 10/50: loss=-1.2449, reward=-236.8600, makespan=236.9
#  Batch 20/50: loss=-1.4896, reward=-227.3467, makespan=227.3
#  Batch 30/50: loss=-1.7820, reward=-233.7000, makespan=233.7
#  Batch 40/50: loss=-2.4649, reward=-223.2800, makespan=223.3
#  Batch 50/50: loss=-2.5565, reward=-233.9333, makespan=233.9
# [Epoch 94] => loss=-1.6492, reward=-231.1112, makespan=231.1
# [Epoch 94 학습 시간] : 39.18 초
#
# Evaluating...
# Evaluation 94 => makespan = 231.54333114624023
# Evaluation 94 평가 시간 : 4.70 초
#
# === [Epoch 95/300] ===
#  Batch 10/50: loss=-0.9320, reward=-235.7800, makespan=235.8
#  Batch 20/50: loss=-1.2182, reward=-229.9800, makespan=230.0
#  Batch 30/50: loss=-3.4695, reward=-232.2067, makespan=232.2
#  Batch 40/50: loss=-2.4883, reward=-229.2333, makespan=229.2
# ...
#
# Evaluating...
# Evaluation 269 => makespan = 225.5299949645996
# Evaluation 269 평가 시간 : 4.67 초
#
# === [Epoch 270/300] ===
#  Batch 10/50: loss=-0.7473, reward=-221.6867, makespan=221.7
#  Batch 20/50: loss=-1.2389, reward=-228.3000, makespan=228.3
#  Batch 30/50: loss=-1.8522, reward=-222.5000, makespan=222.5
#  Batch 40/50: loss=-1.9145, reward=-228.8733, makespan=228.9
#  Batch 50/50: loss=-1.2720, reward=-222.3333, makespan=222.3
# [Epoch 270] => loss=-0.8646, reward=-227.4768, makespan=227.5
# [Epoch 270 학습 시간] : 38.48 초
#
# Evaluating...
# Evaluation 270 => makespan = 224.90332794189453
# Evaluation 270 평가 시간 : 4.57 초
#
# === [Epoch 271/300] ===
#  Batch 10/50: loss=-0.6471, reward=-227.2733, makespan=227.3
#  Batch 20/50: loss=-2.1642, reward=-216.5000, makespan=216.5
#  Batch 30/50: loss=-0.1807, reward=-226.5200, makespan=226.5
#  Batch 40/50: loss=0.0510, reward=-216.8667, makespan=216.9
#  Batch 50/50: loss=-1.2156, reward=-230.4067, makespan=230.4
# [Epoch 271] => loss=-0.8823, reward=-227.6248, makespan=227.6
# [Epoch 271 학습 시간] : 38.74 초
#
# Evaluating...
# Evaluation 271 => makespan = 225.21999486287436
# Evaluation 271 평가 시간 : 4.87 초
#
# === [Epoch 272/300] ===
#  Batch 10/50: loss=-1.4707, reward=-226.8933, makespan=226.9
#  Batch 20/50: loss=-0.3086, reward=-231.4400, makespan=231.4
#  Batch 30/50: loss=-0.5990, reward=-223.3933, makespan=223.4
#  Batch 40/50: loss=-0.5600, reward=-229.3733, makespan=229.4
#  Batch 50/50: loss=0.0579, reward=-224.0533, makespan=224.1
# [Epoch 272] => loss=-0.8293, reward=-227.6051, makespan=227.6
# [Epoch 272 학습 시간] : 39.08 초
#
# Evaluating...
# Evaluation 272 => makespan = 226.76999537150064
# Evaluation 272 평가 시간 : 4.65 초
#
# === [Epoch 273/300] ===
#  Batch 10/50: loss=-1.8583, reward=-229.8733, makespan=229.9
#  Batch 20/50: loss=-1.1861, reward=-235.0133, makespan=235.0
#  Batch 30/50: loss=-0.5160, reward=-227.3867, makespan=227.4
#  Batch 40/50: loss=-0.9470, reward=-232.8133, makespan=232.8
#  Batch 50/50: loss=-2.1851, reward=-225.6000, makespan=225.6
# [Epoch 273] => loss=-0.8221, reward=-226.9593, makespan=227.0
# [Epoch 273 학습 시간] : 38.61 초
#
# Evaluating...
# Evaluation 273 => makespan = 224.93999608357748
# Evaluation 273 평가 시간 : 4.69 초
#
# === [Epoch 274/300] ===
#  Batch 10/50: loss=-0.5080, reward=-227.0200, makespan=227.0
#  Batch 20/50: loss=0.6744, reward=-228.3000, makespan=228.3
#  Batch 30/50: loss=-1.2476, reward=-226.0333, makespan=226.0
#  Batch 40/50: loss=-3.0564, reward=-225.2800, makespan=225.3
#  Batch 50/50: loss=-1.5741, reward=-224.5533, makespan=224.6
# [Epoch 274] => loss=-0.8581, reward=-227.5065, makespan=227.5
# [Epoch 274 학습 시간] : 38.32 초
#
# Evaluating...
# Evaluation 274 => makespan = 225.31666056315103
# Evaluation 274 평가 시간 : 4.74 초
#
# === [Epoch 275/300] ===
#  Batch 10/50: loss=-0.6743, reward=-223.5067, makespan=223.5
#  Batch 20/50: loss=-2.3517, reward=-226.4800, makespan=226.5
#  Batch 30/50: loss=-1.1951, reward=-222.6667, makespan=222.7
#  Batch 40/50: loss=-1.8220, reward=-228.1867, makespan=228.2
#  Batch 50/50: loss=-3.0571, reward=-223.9267, makespan=223.9
# [Epoch 275] => loss=-0.9084, reward=-227.9535, makespan=228.0
# [Epoch 275 학습 시간] : 38.35 초
#
# Evaluating...
# Evaluation 275 => makespan = 226.44999567667642
# Evaluation 275 평가 시간 : 4.59 초
#
# === [Epoch 276/300] ===
#  Batch 10/50: loss=-0.4531, reward=-230.7400, makespan=230.7
#  Batch 20/50: loss=-0.0514, reward=-222.5067, makespan=222.5
#  Batch 30/50: loss=-1.7180, reward=-229.7000, makespan=229.7
#  Batch 40/50: loss=-0.6489, reward=-222.8067, makespan=222.8
#  Batch 50/50: loss=-1.1814, reward=-228.9400, makespan=228.9
# [Epoch 276] => loss=-0.7368, reward=-227.5004, makespan=227.5
# [Epoch 276 학습 시간] : 38.49 초
#
# Evaluating...
# Evaluation 276 => makespan = 227.61332575480142
# Evaluation 276 평가 시간 : 4.67 초
#
# === [Epoch 277/300] ===
#  Batch 10/50: loss=-0.2654, reward=-214.9733, makespan=215.0
#  Batch 20/50: loss=0.4584, reward=-230.4533, makespan=230.5
#  Batch 30/50: loss=-0.9909, reward=-216.8667, makespan=216.9
#  Batch 40/50: loss=-1.5674, reward=-234.1533, makespan=234.2
#  Batch 50/50: loss=-0.4459, reward=-218.8533, makespan=218.9
# [Epoch 277] => loss=-0.8443, reward=-227.0041, makespan=227.0
# [Epoch 277 학습 시간] : 39.38 초
#
# Evaluating...
# Evaluation 277 => makespan = 226.7899958292643
# Evaluation 277 평가 시간 : 4.71 초
#
# === [Epoch 278/300] ===
#  Batch 10/50: loss=0.1336, reward=-232.0067, makespan=232.0
#  Batch 20/50: loss=-1.6583, reward=-223.6333, makespan=223.6
#  Batch 30/50: loss=-0.9690, reward=-227.2133, makespan=227.2
#  Batch 40/50: loss=-0.9212, reward=-218.9333, makespan=218.9
#  Batch 50/50: loss=-0.4990, reward=-229.1800, makespan=229.2
# [Epoch 278] => loss=-0.7307, reward=-227.0747, makespan=227.1
# [Epoch 278 학습 시간] : 38.73 초
#
# Evaluating...
# Evaluation 278 => makespan = 227.80332692464194
# Evaluation 278 평가 시간 : 4.69 초
#
# === [Epoch 279/300] ===
#  Batch 10/50: loss=-1.1127, reward=-233.0067, makespan=233.0
#  Batch 20/50: loss=-0.1265, reward=-225.1333, makespan=225.1
#  Batch 30/50: loss=-0.2019, reward=-230.8467, makespan=230.8
#  Batch 40/50: loss=-1.0047, reward=-227.1533, makespan=227.2
#  Batch 50/50: loss=-0.8323, reward=-231.2133, makespan=231.2
# [Epoch 279] => loss=-0.8151, reward=-227.3363, makespan=227.3
# [Epoch 279 학습 시간] : 38.53 초
#
# Evaluating...
# Evaluation 279 => makespan = 226.91666412353516
# Evaluation 279 평가 시간 : 4.69 초
#
# === [Epoch 280/300] ===
#  Batch 10/50: loss=-1.0903, reward=-225.4733, makespan=225.5
#  Batch 20/50: loss=-1.0669, reward=-223.6867, makespan=223.7
#  Batch 30/50: loss=-0.6245, reward=-226.7667, makespan=226.8
#  Batch 40/50: loss=-0.7483, reward=-228.4800, makespan=228.5
#  Batch 50/50: loss=-0.5925, reward=-232.7733, makespan=232.8
# [Epoch 280] => loss=-0.7690, reward=-227.1669, makespan=227.2
# [Epoch 280 학습 시간] : 39.09 초
#
# Evaluating...
# Evaluation 280 => makespan = 228.85665893554688
# Evaluation 280 평가 시간 : 4.75 초
#
# === [Epoch 281/300] ===
#  Batch 10/50: loss=0.3442, reward=-232.4667, makespan=232.5
#  Batch 20/50: loss=-0.6277, reward=-225.5933, makespan=225.6
#  Batch 30/50: loss=0.0735, reward=-231.5067, makespan=231.5
#  Batch 40/50: loss=-0.4095, reward=-226.8133, makespan=226.8
#  Batch 50/50: loss=0.2600, reward=-228.0933, makespan=228.1
# [Epoch 281] => loss=-0.6208, reward=-230.0028, makespan=230.0
# [Epoch 281 학습 시간] : 38.78 초
#
# Evaluating...
# Evaluation 281 => makespan = 227.67999649047852
# Evaluation 281 평가 시간 : 4.68 초
#
# === [Epoch 282/300] ===
#  Batch 10/50: loss=-0.4331, reward=-228.3800, makespan=228.4
#  Batch 20/50: loss=0.2599, reward=-228.5933, makespan=228.6
#  Batch 30/50: loss=-2.3287, reward=-226.6667, makespan=226.7
#  Batch 40/50: loss=-1.2911, reward=-228.4333, makespan=228.4
#  Batch 50/50: loss=1.2313, reward=-229.3000, makespan=229.3
# [Epoch 282] => loss=-0.9387, reward=-228.9309, makespan=228.9
# [Epoch 282 학습 시간] : 38.47 초
#
# Evaluating...
# Evaluation 282 => makespan = 228.0833282470703
# Evaluation 282 평가 시간 : 4.65 초
#
# === [Epoch 283/300] ===
#  Batch 10/50: loss=-0.8980, reward=-235.0200, makespan=235.0
#  Batch 20/50: loss=-0.2880, reward=-219.7667, makespan=219.8
#  Batch 30/50: loss=-0.1932, reward=-234.0800, makespan=234.1
#  Batch 40/50: loss=0.2870, reward=-223.6200, makespan=223.6
#  Batch 50/50: loss=-1.7959, reward=-235.1333, makespan=235.1
# [Epoch 283] => loss=-0.8558, reward=-228.1120, makespan=228.1
# [Epoch 283 학습 시간] : 38.28 초
#
# Evaluating...
# Evaluation 283 => makespan = 226.66666412353516
# Evaluation 283 평가 시간 : 4.71 초
#
# === [Epoch 284/300] ===
#  Batch 10/50: loss=-0.5275, reward=-223.6667, makespan=223.7
#  Batch 20/50: loss=0.3951, reward=-234.2267, makespan=234.2
#  Batch 30/50: loss=-0.3713, reward=-221.5400, makespan=221.5
#  Batch 40/50: loss=-1.4062, reward=-229.0867, makespan=229.1
#  Batch 50/50: loss=-0.8335, reward=-222.7333, makespan=222.7
# [Epoch 284] => loss=-0.7193, reward=-228.4232, makespan=228.4
# [Epoch 284 학습 시간] : 38.28 초
#
# Evaluating...
# Evaluation 284 => makespan = 225.18666076660156
# Evaluation 284 평가 시간 : 4.58 초
#
# === [Epoch 285/300] ===
#  Batch 10/50: loss=-0.6662, reward=-229.8600, makespan=229.9
#  Batch 20/50: loss=0.8345, reward=-230.7667, makespan=230.8
#  Batch 30/50: loss=0.1592, reward=-224.8067, makespan=224.8
#  Batch 40/50: loss=-0.1741, reward=-229.4200, makespan=229.4
#  Batch 50/50: loss=-0.3034, reward=-223.7400, makespan=223.7
# [Epoch 285] => loss=-0.6778, reward=-227.2887, makespan=227.3
# [Epoch 285 학습 시간] : 38.79 초
#
# Evaluating...
# Evaluation 285 => makespan = 225.59332911173502
# Evaluation 285 평가 시간 : 4.81 초
#
# === [Epoch 286/300] ===
#  Batch 10/50: loss=-0.0032, reward=-225.5467, makespan=225.5
#  Batch 20/50: loss=-1.8669, reward=-233.9800, makespan=234.0
#  Batch 30/50: loss=-1.3029, reward=-229.1067, makespan=229.1
#  Batch 40/50: loss=-1.2706, reward=-237.9200, makespan=237.9
#  Batch 50/50: loss=0.2244, reward=-227.8867, makespan=227.9
# [Epoch 286] => loss=-0.7248, reward=-227.7567, makespan=227.8
# [Epoch 286 학습 시간] : 39.11 초
#
# Evaluating...
# Evaluation 286 => makespan = 227.0299949645996
# Evaluation 286 평가 시간 : 4.59 초
#
# === [Epoch 287/300] ===
#  Batch 10/50: loss=-0.8455, reward=-223.4267, makespan=223.4
#  Batch 20/50: loss=-0.6490, reward=-227.7467, makespan=227.7
#  Batch 30/50: loss=-0.3435, reward=-224.8133, makespan=224.8
#  Batch 40/50: loss=-0.9350, reward=-229.4600, makespan=229.5
#  Batch 50/50: loss=-0.0918, reward=-222.3933, makespan=222.4
# [Epoch 287] => loss=-0.6909, reward=-228.6661, makespan=228.7
# [Epoch 287 학습 시간] : 38.54 초
#
# Evaluating...
# Evaluation 287 => makespan = 225.42666244506836
# Evaluation 287 평가 시간 : 4.68 초
#
# === [Epoch 288/300] ===
#  Batch 10/50: loss=-1.0524, reward=-225.9333, makespan=225.9
#  Batch 20/50: loss=-1.9913, reward=-227.1933, makespan=227.2
#  Batch 30/50: loss=-1.5467, reward=-224.2600, makespan=224.3
#  Batch 40/50: loss=0.5762, reward=-226.7133, makespan=226.7
#  Batch 50/50: loss=-0.6136, reward=-226.6000, makespan=226.6
# [Epoch 288] => loss=-0.8926, reward=-227.2933, makespan=227.3
# [Epoch 288 학습 시간] : 39.03 초
#
# Evaluating...
# Evaluation 288 => makespan = 227.89999516805014
# Evaluation 288 평가 시간 : 4.73 초
#
# === [Epoch 289/300] ===
#  Batch 10/50: loss=-1.4565, reward=-222.6600, makespan=222.7
#  Batch 20/50: loss=-0.9331, reward=-236.8200, makespan=236.8
#  Batch 30/50: loss=-2.0062, reward=-221.7467, makespan=221.7
#  Batch 40/50: loss=-0.9602, reward=-233.9000, makespan=233.9
#  Batch 50/50: loss=-0.7760, reward=-223.8200, makespan=223.8
# [Epoch 289] => loss=-0.9333, reward=-227.0968, makespan=227.1
# [Epoch 289 학습 시간] : 38.94 초
#
# Evaluating...
# Evaluation 289 => makespan = 226.4866625467936
# Evaluation 289 평가 시간 : 4.70 초
#
# === [Epoch 290/300] ===
#  Batch 10/50: loss=-1.1051, reward=-229.8133, makespan=229.8
#  Batch 20/50: loss=-0.5123, reward=-222.5867, makespan=222.6
#  Batch 30/50: loss=-0.2074, reward=-230.3467, makespan=230.3
#  Batch 40/50: loss=-1.9314, reward=-223.4333, makespan=223.4
#  Batch 50/50: loss=-0.5818, reward=-228.4533, makespan=228.5
# [Epoch 290] => loss=-0.7769, reward=-228.2799, makespan=228.3
# [Epoch 290 학습 시간] : 38.63 초
#
# Evaluating...
# Evaluation 290 => makespan = 229.5399958292643
# Evaluation 290 평가 시간 : 4.63 초
#
# === [Epoch 291/300] ===
#  Batch 10/50: loss=-2.2156, reward=-228.5067, makespan=228.5
#  Batch 20/50: loss=-0.4413, reward=-224.8400, makespan=224.8
#  Batch 30/50: loss=-1.3662, reward=-228.9600, makespan=229.0
#  Batch 40/50: loss=0.1863, reward=-230.5400, makespan=230.5
#  Batch 50/50: loss=-0.6557, reward=-230.3933, makespan=230.4
# [Epoch 291] => loss=-0.6813, reward=-227.9756, makespan=228.0
# [Epoch 291 학습 시간] : 38.53 초
#
# Evaluating...
# Evaluation 291 => makespan = 227.42332712809244
# Evaluation 291 평가 시간 : 4.66 초
#
# === [Epoch 292/300] ===
#  Batch 10/50: loss=-0.5646, reward=-233.0733, makespan=233.1
#  Batch 20/50: loss=0.1533, reward=-230.2133, makespan=230.2
#  Batch 30/50: loss=-0.0404, reward=-235.2133, makespan=235.2
#  Batch 40/50: loss=0.3250, reward=-230.6067, makespan=230.6
#  Batch 50/50: loss=-0.2587, reward=-234.0800, makespan=234.1
# [Epoch 292] => loss=-0.6982, reward=-227.8668, makespan=227.9
# [Epoch 292 학습 시간] : 38.58 초
#
# Evaluating...
# Evaluation 292 => makespan = 226.24999491373697
# Evaluation 292 평가 시간 : 4.69 초
#
# === [Epoch 293/300] ===
#  Batch 10/50: loss=-1.6072, reward=-230.6400, makespan=230.6
#  Batch 20/50: loss=-1.2242, reward=-224.2533, makespan=224.3
#  Batch 30/50: loss=-0.0815, reward=-228.7467, makespan=228.7
#  Batch 40/50: loss=-0.4824, reward=-225.1333, makespan=225.1
#  Batch 50/50: loss=-0.2099, reward=-228.9667, makespan=229.0
# [Epoch 293] => loss=-0.8073, reward=-227.6137, makespan=227.6
# [Epoch 293 학습 시간] : 38.42 초
#
# Evaluating...
# Evaluation 293 => makespan = 226.3233273824056
# Evaluation 293 평가 시간 : 4.79 초
#
# === [Epoch 294/300] ===
#  Batch 10/50: loss=0.0403, reward=-229.7733, makespan=229.8
#  Batch 20/50: loss=0.0821, reward=-228.0867, makespan=228.1
#  Batch 30/50: loss=-1.9323, reward=-229.8067, makespan=229.8
#  Batch 40/50: loss=-1.0872, reward=-226.7800, makespan=226.8
#  Batch 50/50: loss=-2.5912, reward=-231.3867, makespan=231.4
# [Epoch 294] => loss=-0.7032, reward=-229.0861, makespan=229.1
# [Epoch 294 학습 시간] : 39.14 초
#
# Evaluating...
# Evaluation 294 => makespan = 225.6266632080078
# Evaluation 294 평가 시간 : 4.80 초
#
# === [Epoch 295/300] ===
#  Batch 10/50: loss=-3.0230, reward=-234.1800, makespan=234.2
#  Batch 20/50: loss=0.4210, reward=-226.9200, makespan=226.9
#  Batch 30/50: loss=-0.5186, reward=-231.7667, makespan=231.8
#  Batch 40/50: loss=-1.0392, reward=-225.5333, makespan=225.5
#  Batch 50/50: loss=-1.4760, reward=-230.0467, makespan=230.0
# [Epoch 295] => loss=-0.7719, reward=-228.2572, makespan=228.3
# [Epoch 295 학습 시간] : 38.39 초
#
# Evaluating...
# Evaluation 295 => makespan = 225.77999623616537
# Evaluation 295 평가 시간 : 4.63 초
#
# === [Epoch 296/300] ===
#  Batch 10/50: loss=-1.2403, reward=-223.0067, makespan=223.0
#  Batch 20/50: loss=-0.7102, reward=-225.5200, makespan=225.5
#  Batch 30/50: loss=-0.8186, reward=-225.6467, makespan=225.6
#  Batch 40/50: loss=-1.1770, reward=-222.9333, makespan=222.9
#  Batch 50/50: loss=-0.8590, reward=-227.2467, makespan=227.2
# [Epoch 296] => loss=-0.8682, reward=-227.4224, makespan=227.4
# [Epoch 296 학습 시간] : 38.93 초
#
# Evaluating...
# Evaluation 296 => makespan = 226.41999435424805
# Evaluation 296 평가 시간 : 4.75 초
#
# === [Epoch 297/300] ===
#  Batch 10/50: loss=-0.3109, reward=-229.4400, makespan=229.4
#  Batch 20/50: loss=0.9558, reward=-231.1067, makespan=231.1
#  Batch 30/50: loss=-1.8230, reward=-228.8933, makespan=228.9
#  Batch 40/50: loss=-1.1627, reward=-230.6867, makespan=230.7
#  Batch 50/50: loss=-0.2133, reward=-231.0200, makespan=231.0
# [Epoch 297] => loss=-0.8983, reward=-227.1053, makespan=227.1
# [Epoch 297 학습 시간] : 39.31 초
#
# Evaluating...
# Evaluation 297 => makespan = 225.60666275024414
# Evaluation 297 평가 시간 : 4.63 초
#
# === [Epoch 298/300] ===
#  Batch 10/50: loss=-0.7616, reward=-227.3067, makespan=227.3
#  Batch 20/50: loss=-0.3675, reward=-235.2067, makespan=235.2
#  Batch 30/50: loss=-1.2370, reward=-228.4333, makespan=228.4
#  Batch 40/50: loss=0.1509, reward=-238.2800, makespan=238.3
#  Batch 50/50: loss=-0.5504, reward=-231.8200, makespan=231.8
# [Epoch 298] => loss=-0.9685, reward=-226.8287, makespan=226.8
# [Epoch 298 학습 시간] : 37.45 초
#
# Evaluating...
# Evaluation 298 => makespan = 227.5399958292643
# Evaluation 298 평가 시간 : 4.65 초
#
# === [Epoch 299/300] ===
#  Batch 10/50: loss=-0.8050, reward=-223.7933, makespan=223.8
#  Batch 20/50: loss=-0.6523, reward=-228.1000, makespan=228.1
#  Batch 30/50: loss=-1.2467, reward=-222.8267, makespan=222.8
#  Batch 40/50: loss=-0.2520, reward=-228.5733, makespan=228.6
#  Batch 50/50: loss=-0.5299, reward=-223.3933, makespan=223.4
# [Epoch 299] => loss=-0.7543, reward=-227.1163, makespan=227.1
# [Epoch 299 학습 시간] : 37.36 초
#
# Evaluating...
# Evaluation 299 => makespan = 225.5566635131836
# Evaluation 299 평가 시간 : 4.51 초
#
# === [Epoch 300/300] ===
#  Batch 10/50: loss=-1.3553, reward=-225.0400, makespan=225.0
#  Batch 20/50: loss=-1.3480, reward=-228.6133, makespan=228.6
#  Batch 30/50: loss=-0.0684, reward=-223.6800, makespan=223.7
#  Batch 40/50: loss=-0.7680, reward=-229.1067, makespan=229.1
#  Batch 50/50: loss=-1.0898, reward=-223.2267, makespan=223.2
# [Epoch 300] => loss=-0.7067, reward=-226.6356, makespan=226.6
# [Epoch 300 학습 시간] : 37.35 초
#
# Evaluating...
# Evaluation 300 => makespan = 226.90332667032877
# Evaluation 300 평가 시간 : 4.66 초
#
# 전체 학습 시간 : 216분 38초

# %% [markdown]
# ## 모델 저장

# %%
import os

def save_agent(agent, path):
    """
    Save the REINFORCE agent's state
    """
    save_dict = {
        'policy_net_state': agent.policy_net.state_dict(),
        'optimizer_state': agent.optimizer.state_dict(),
        'machine_names': agent.machine_names,
        'num_actions': agent.num_actions,
        'device': agent.device
    }
    torch.save(save_dict, path)

def load_agent(path, state_dim, hidden_dim, num_layers, lr=1e-3):
    """
    Load a saved REINFORCE agent
    """
    checkpoint = torch.load(path)
    
    # Recreate agent with saved parameters
    agent = REINFORCEAgent(
        state_dim=state_dim,
        hidden_dim=hidden_dim,
        num_layers=num_layers,
        num_actions=checkpoint['num_actions'],
        machine_names=checkpoint['machine_names'],
        lr=lr,
        device=checkpoint['device']
    )
    
    # Load saved states
    agent.policy_net.load_state_dict(checkpoint['policy_net_state'])
    agent.optimizer.load_state_dict(checkpoint['optimizer_state'])
    
    return agent

# Save agent
save_path = './POMO_model/20_lots/reinforce_agent_3machine.pth'
# save_agent(trained_agent, save_path)

# Load agent
# loaded_agent = load_agent(
#     path='reinforce_agent.pth',
#     state_dim=state_dim,  # Use same dimensions as original agent
#     hidden_dim=hidden_dim,
#     num_layers=num_layers
# )

# %% [markdown]
# ## 테스트 데이터 시각화

# %% [markdown]
# # 10 Lots

# %%
# 환경 파라미터
num_lots = 10
num_machines = 3

num_processes = num_lots // 2  # Process_ID의 개수는 로트 개수의 절반
num_masks = num_machines  # 전체 마스크의 개수는 기계 수와 같음
min_machines_per_process = 2
max_machines_per_process = 3
min_masks_per_combo = 2
max_masks_per_combo = 3
min_masks_per_process = 2
max_masks_per_process = 3
min_processing_time = 20
max_processing_time = 50
interval_size=5

# 1) dummy로 env/agent 준비
dummy_data = generate_instance_data()
machines = extract_machine_names(dummy_data)
dummy_env = ParallelMachineEnvTimeProgressPOMO(dummy_data["lots"], dummy_data["process_info"], machines)
dummy_state = dummy_env.reset()
state_dim = len(dummy_state) if isinstance(dummy_state, (list, tuple)) else dummy_state.shape[-1]
num_actions = len(machines)

trained_agent = load_agent(
    path='./POMO_model/10_lots/reinforce_agent_3machine.pth',
    state_dim=state_dim,
    hidden_dim=128, 
    num_layers=2
)
# Out:
# C:\Users\daftg\AppData\Local\Temp\ipykernel_141504\2737848824.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path)

# %%
# 간트 차트 시각화화
instance_data = generate_instance_data()
machines = extract_machine_names(instance_data)

fig, ax, history = create_pomo_gantt_chart(instance_data, trained_agent, machines)

print("\n작업 상세:")
for job in history:
    print(f"Machine: {job['machine']}, "
          f"Lot: {job['lot_id']}, "
          f"Process: {job['process_id']}, "
          f"Time: {job['start_time']} -> {job['start_time'] + job['duration']}")

plt.show()
# Out:
# Best POMO Solution:
# Makespan: 126.00
# Total jobs completed: 10
#
# 작업 상세:
# Machine: M1, Lot: L01, Process: P03, Time: 0 -> 25
# Machine: M3, Lot: L04, Process: P04, Time: 19 -> 48
# Machine: M2, Lot: L02, Process: P02, Time: 5 -> 49
# Machine: M1, Lot: L05, Process: P05, Time: 25 -> 62
# Machine: M2, Lot: L03, Process: P01, Time: 49 -> 71
# Machine: M3, Lot: L08, Process: P04, Time: 48 -> 77
# Machine: M1, Lot: L07, Process: P03, Time: 62 -> 87
# Machine: M2, Lot: L09, Process: P01, Time: 71 -> 93
# Machine: M1, Lot: L06, Process: P05, Time: 87 -> 124
# Machine: M3, Lot: L10, Process: P02, Time: 77 -> 125

# %% [markdown]
# # 20 Lots

# %%
num_lots = 20
num_machines = 4

num_processes = num_lots // 2  # Process_ID의 개수는 로트 개수의 절반
num_masks = num_machines  # 전체 마스크의 개수는 기계 수와 같음
min_machines_per_process = 2
max_machines_per_process = 3
min_masks_per_combo = 2
max_masks_per_combo = 3
min_masks_per_process = 2
max_masks_per_process = 3
min_processing_time = 20
max_processing_time = 50
interval_size=5

seed =  random.randint(1, 1000000)

# 1) dummy로 env/agent 준비
dummy_data = generate_instance_data(seed = seed)
machines = extract_machine_names(dummy_data)
dummy_env = ParallelMachineEnvTimeProgressPOMO(dummy_data["lots"], dummy_data["process_info"], machines)
dummy_state = dummy_env.reset()
state_dim = len(dummy_state) if isinstance(dummy_state, (list, tuple)) else dummy_state.shape[-1]
num_actions = len(machines)

trained_agent = load_agent(
    path='./POMO_model/20_lots/reinforce_agent_4machine.pth',
    state_dim=state_dim,
    hidden_dim=128, 
    num_layers=2
)

instance_data = generate_instance_data(seed = None)
machines = extract_machine_names(instance_data)

fig, ax, history = create_pomo_gantt_chart(instance_data, trained_agent, machines)

print("\n작업 상세:")
for job in history:
    print(f"Machine: {job['machine']}, "
          f"Lot: {job['lot_id']}, "
          f"Process: {job['process_id']}, "
          f"Time: {job['start_time']} -> {job['start_time'] + job['duration']}")

plt.show()

print(seed)
# Out:
# Best POMO Solution:
# Makespan: 193.00
# Total jobs completed: 20
#
# 작업 상세:
# Machine: M2, Lot: L02, Process: P06, Time: 5 -> 25
# Machine: M3, Lot: L01, Process: P05, Time: 1 -> 33
# Machine: M1, Lot: L04, Process: P01, Time: 19 -> 51
# Machine: M2, Lot: L03, Process: P07, Time: 25 -> 53
# Machine: M3, Lot: L07, Process: P03, Time: 34 -> 67
# Machine: M2, Lot: L11, Process: P06, Time: 53 -> 73
# Machine: M4, Lot: L09, Process: P10, Time: 45 -> 74
# Machine: M4, Lot: L12, Process: P03, Time: 74 -> 96
# Machine: M1, Lot: L05, Process: P04, Time: 53 -> 98
# Machine: M3, Lot: L08, Process: P02, Time: 67 -> 103
# Machine: M2, Lot: L18, Process: P01, Time: 88 -> 112
# Machine: M4, Lot: L13, Process: P02, Time: 96 -> 121
# Machine: M1, Lot: L15, Process: P10, Time: 98 -> 128
# Machine: M2, Lot: L19, Process: P07, Time: 112 -> 140
# Machine: M3, Lot: L14, Process: P08, Time: 103 -> 151
# Machine: M1, Lot: L10, Process: P09, Time: 140 -> 166
# Machine: M4, Lot: L06, Process: P08, Time: 121 -> 170
# Machine: M3, Lot: L17, Process: P05, Time: 151 -> 183
# Machine: M2, Lot: L16, Process: P04, Time: 152 -> 191
# Machine: M1, Lot: L20, Process: P09, Time: 166 -> 192
# C:\Users\daftg\AppData\Local\Temp\ipykernel_141504\2737848824.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path)
# 730388
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
